# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests, re

# %%
url = "http://digilib.uad.ac.id//penelitian/Penelitian/index/::::--forensic::5000"
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
div_block = soup.findAll('div', attrs={"class": "news_item"})

# %%
data = list()
for doc in div_block:
    title = doc.find("h3").contents[0].text
    title = re.sub(r'[\r\n]','',title).split(" ")
    title = ' '.join([i for i in title if i is not ""])
    try:
        obj = {
            "author": doc.find("br").previousSibling.split(":")[1].title(),
            "title": title.title(),
            "url": doc.find("h3").contents[0].attrs["href"],
            "year": doc.findAll("br")[1].nextSibling.split(",")[2]
        }
        data.append(obj)
    except IndexError:
        pass

# %%
df = pd.DataFrame(data)
df
# Out:
#                          author  \
# 0             Muhammad Nur Faiz
# 1             Diah Ayu Septiani
# 2        Mada Satya Bayu Ambika
# 3                      Mu Minin
# 4                Rizky Yogatama
# 5           Arif Roid Caesarano
# 6                 Imam Suryanto
# 7          Ahmad Muhammad Ridho
# 8      Bashor Fauzan Muthohirin
# 9                  Faizin Ridho
# 10              Nita Hildayanti
# 11               Agus Dwi Putra
# 12                 Dedy Saputra
# 13   Dewi Estri Jayanti Harahap
# 14                   Sahiruddin
#
#                                                 title  \
# 0   Pengembangan Proses Investigasi Untuk Analisis...
# 1   Police Investigation Interview Strategy To Vic...
# 2   Mobile Forensic Instant Messenger Berbasis And...
# 3   Live Data Forensic Artefak Internet Browser Go...
# 4   Investigasi Artifact Internet Browser Forensic...
# 5   Forensik Jaringan Untuk Mendeteksi Serangan Sq...
# 6   Forensic Mobile Pada Aplikasi Android E-Commer...
# 7   Cloud Forensics Investigation Pada Cloud Stora...
# 8   Analisis Live Forensics Pada E-Mail Sebagai Ba...
# 9   Analisis Forensik Router Terhadap Serangan Dis...
# 10  Analisis Forensik Router Pada Jaringan Kompute...
# 11  Analisis Forensik Pada Serangan Spamming Email...
# 12  Analisis Forensik Jaringan Terhadap Serangan M...
# 13  Analisis Forensik Digital Storage Pada Ownclou...
# 14  Analisis Forensik Data Recovery Pada Smartphon...
#
#                                                   url   year
# 0   http://digilib.uad.ac.id/penelitian/Penelitian...   2018
# 1   http://digilib.uad.ac.id/penelitian/Penelitian...   2018
# 2   http://digilib.uad.ac.id/penelitian/Penelitian...   2019
# 3   http://digilib.uad.ac.id/penelitian/Penelitian...   2019
# 4   http://digilib.uad.ac.id/penelitian/Penelitian...   2018
# 5   http://digilib.uad.ac.id/penelitian/Penelitian...   2018
# 6   http://digilib.uad.ac.id/penelitian/Penelitian...   2019
# 7   http://digilib.uad.ac.id/penelitian/Penelitian...   2019
# 8   http://digilib.uad.ac.id/penelitian/Penelitian...   2019
# 9   http://digilib.uad.ac.id/penelitian/Penelitian...   2018
# 10  http://digilib.uad.ac.id/penelitian/Penelitian...   2018
# 11  http://digilib.uad.ac.id/penelitian/Penelitian...   2019
# 12  http://digilib.uad.ac.id/penelitian/Penelitian...   2018
# 13  http://digilib.uad.ac.id/penelitian/Penelitian...   2019
# 14  http://digilib.uad.ac.id/penelitian/Penelitian...   2019

# %%
df.to_excel("dataset_scrapper.xlsx", index=False)

# %%
data_scrapper = pd.read_excel("dataset_scrapper.xlsx")
data_scrapper
# Out:
#                          author  \
# 0             Muhammad Nur Faiz
# 1             Diah Ayu Septiani
# 2        Mada Satya Bayu Ambika
# 3                      Mu Minin
# 4                Rizky Yogatama
# 5           Arif Roid Caesarano
# 6                 Imam Suryanto
# 7          Ahmad Muhammad Ridho
# 8      Bashor Fauzan Muthohirin
# 9                  Faizin Ridho
# 10              Nita Hildayanti
# 11               Agus Dwi Putra
# 12                 Dedy Saputra
# 13   Dewi Estri Jayanti Harahap
# 14                   Sahiruddin
#
#                                                 title  \
# 0   Pengembangan Proses Investigasi Untuk Analisis...
# 1   Police Investigation Interview Strategy To Vic...
# 2   Mobile Forensic Instant Messenger Berbasis And...
# 3   Live Data Forensic Artefak Internet Browser Go...
# 4   Investigasi Artifact Internet Browser Forensic...
# 5   Forensik Jaringan Untuk Mendeteksi Serangan Sq...
# 6   Forensic Mobile Pada Aplikasi Android E-Commer...
# 7   Cloud Forensics Investigation Pada Cloud Stora...
# 8   Analisis Live Forensics Pada E-Mail Sebagai Ba...
# 9   Analisis Forensik Router Terhadap Serangan Dis...
# 10  Analisis Forensik Router Pada Jaringan Kompute...
# 11  Analisis Forensik Pada Serangan Spamming Email...
# 12  Analisis Forensik Jaringan Terhadap Serangan M...
# 13  Analisis Forensik Digital Storage Pada Ownclou...
# 14  Analisis Forensik Data Recovery Pada Smartphon...
#
#                                                   url  year
# 0   http://digilib.uad.ac.id/penelitian/Penelitian...  2018
# 1   http://digilib.uad.ac.id/penelitian/Penelitian...  2018
# 2   http://digilib.uad.ac.id/penelitian/Penelitian...  2019
# 3   http://digilib.uad.ac.id/penelitian/Penelitian...  2019
# 4   http://digilib.uad.ac.id/penelitian/Penelitian...  2018
# 5   http://digilib.uad.ac.id/penelitian/Penelitian...  2018
# 6   http://digilib.uad.ac.id/penelitian/Penelitian...  2019
# 7   http://digilib.uad.ac.id/penelitian/Penelitian...  2019
# 8   http://digilib.uad.ac.id/penelitian/Penelitian...  2019
# 9   http://digilib.uad.ac.id/penelitian/Penelitian...  2018
# 10  http://digilib.uad.ac.id/penelitian/Penelitian...  2018
# 11  http://digilib.uad.ac.id/penelitian/Penelitian...  2019
# 12  http://digilib.uad.ac.id/penelitian/Penelitian...  2018
# 13  http://digilib.uad.ac.id/penelitian/Penelitian...  2019
# 14  http://digilib.uad.ac.id/penelitian/Penelitian...  2019
