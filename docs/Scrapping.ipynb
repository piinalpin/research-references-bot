# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests, re

# %%
url = "http://digilib.uad.ac.id//penelitian/Penelitian/index/::::--data%20mining::5000"
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
div_block = soup.findAll('div', attrs={"class": "news_item"})

# %%
data = list()
for doc in div_block:
    title = doc.find("h3").contents[0].text
    title = re.sub(r'[\r\n]','',title).split(" ")
    title = ' '.join([i for i in title if i is not ""])
    try:
        obj = {
            "author": doc.find("br").previousSibling.split(":")[1].title(),
            "title": title.title(),
            "url": doc.find("h3").contents[0].attrs["href"],
            "year": doc.findAll("br")[1].nextSibling.split(",")[2]
        }
        data.append(obj)
    except IndexError:
        pass

# %%
df = pd.DataFrame(data)
df
# Out:
#                         author  \
# 0            Adnan Ilham Rifai
# 1         Taufik Mufti Haryadi
# 2          Ramon Aswinda Anwar
# 3         Anatasia Hasni Griya
# 4               Rahma Ida Noor
# 5                  Astuti Yuni
# 6             Junaedi Darmawan
# 7                  Adi Romansa
# 8      Arie Swandy Azhari Pora
# 9          Fiqriany Karepesina
# 10             Nanang Yuniarto
# 11        Shaufi Yuliani Putri
# 12      Aline Embun Pramadhani
# 13         Nurul Hudha Setyati
# 14         Aprial Andi Purnama
# 15                  Hariansyah
# 16           Indri Dwi Lestari
# 17                   Jamaludin
# 18    Badaruddin Lalu Saptiadi
# 19                 Mugi Astuti
# 20         Imam Andri Harjanto
# 21                      Fadlin
# 22                Nurhaeka Tou
# 23                   Margareta
# 24         Muhammad Isa Ansori
# 25         Shofwan Hadi Shoufy
# 26                    Prayitno
# 27             Iswanto Bambang
# 28             Parastuti Endah
# 29                 Hadi Wibowo
# 30              Lisna Zuhrotun
# 31               Anna Tiffanie
# 32              Riza Kurniawan
# 33         Rahma Sara Pattihua
# 34                     Haslina
# 35            Bambang Sulistyo
# 36   Kurniadi Galih Anggriawan
# 37              Diah Anggriani
# 38            Rissa Umami Noor
# 39               Kristiani Ana
# 40               Harviana Novi
# 41            Sulistiawati Ria
# 42            Anggit Fikrianto
# 43               Syamsuri Jaya
#
#                                                 title  \
# 0   Rancang Bangun Aplikasi Data Mining Dengan Met...
# 1   Rancang Bangun Data Mining Untuk Mencari Pola ...
# 2   Perancangan Program Aplikasi Untuk Menganalisa...
# 3   Penerapan Data Mining Untuk Mengetahui Faktor-...
# 4   Penerapan Data Mining Untuk Memprediksi Jumlah...
# 5   Penerapan Data Mining Dengan Algoritma Hash-Ba...
# 6   Penerapan Metode Clustering K-Means Untuk Peng...
# 7   Penerapan Data Mining Dengan Algoritma Apriori...
# 8   Penerapan Data Mining Untuk Pengelompokan Data...
# 9   Penerapan Data Mining Untuk Penentuan Penerima...
# 10  Penerapan Data Mining Untuk Menentukan Kelayak...
# 11  Penerapan Data Mining Untuk Melakukan Prediksi...
# 12  Penerapan Data Mining Untuk Klasifikasi Predik...
# 13  Penerapan Data Mining Untuk Klasifikasi Berat ...
# 14  Penerapan Data Mining Untuk Clustering Status ...
# 15  Penerapan Data Mining Untuk Analisis Pola Asos...
# 16  Penerapan Data Mining Menggunakan Metode Naive...
# 17  Penerapan Data Mining Dengan Metode Naive Baye...
# 18  Penerapan Data Mining Dengan Algoritma Asosias...
# 19  Penerapan Data Mining Dalam Pengelompokkan Ban...
# 20  Penerapan Data Mining Dalam Mencari Pola Asosi...
# 21  Penerapan Data Mining Dalam Melakukan Segmenta...
# 22  Penerapan Data Dalam Pengelompokkan Hasil Diag...
# 23  Penentuan Jenis Produksi Teh Hitam Menggunakan...
# 24  Pemanfaatan Data Mining Dalam Segmentasi Pelan...
# 25  Pemanfaatan Data Mining Dalam Monitoring Evalu...
# 26  Klasifikasi Potensi Zakat Di Lazismu Diy Mengg...
# 27  Implementasi Data Mining Menggunakan Algoritma...
# 28  Implementasi Data Mining Algoritma K-Means Clu...
# 29  Implementasi Algoritma Cart Untuk Menemukan Po...
# 30  Implementasi Teknik Data Mining Untuk Customer...
# 31  Implementasi E-Commerce Dengan Data Mining Seb...
# 32  Implementasi Data Mining Untuk Pengelompokan H...
# 33  Implementasi Data Mining Untuk Penentuan Pola ...
# 34  Implementasi Data Mining Untuk Mengelompokkan ...
# 35  Implementasi Data Mining Untuk Memprediksi Lam...
# 36  Implementasi Data Mining Dengan Algoritma Apri...
# 37  Implementasi Data Mining Dan Analisis Pola Aso...
# 38  Implementasi Data Mining Menggunakan Al-Goritm...
# 39  Data Mining Untuk Pengambilan Keputusan Dalam ...
# 40  Data Mining Analisa Transaksi Penjualan Menggu...
# 41  Aplikasi Data Mining Dan Penerapan Fuzzy Madm ...
# 42  Aplikasi Data Mining Untuk Mengklasifikasikan ...
# 43  Aplikasi Data Mining Untuk Mengklasifikasi Pen...
#
#                                                   url   year
# 0   http://digilib.uad.ac.id/penelitian/Penelitian...   2013
# 1   http://digilib.uad.ac.id/penelitian/Penelitian...   2017
# 2   http://digilib.uad.ac.id/penelitian/Penelitian...   2013
# 3   http://digilib.uad.ac.id/penelitian/Penelitian...   2013
# 4   http://digilib.uad.ac.id/penelitian/Penelitian...   2013
# 5   http://digilib.uad.ac.id/penelitian/Penelitian...   2014
# 6   http://digilib.uad.ac.id/penelitian/Penelitian...   2017
# 7   http://digilib.uad.ac.id/penelitian/Penelitian...   2019
# 8   http://digilib.uad.ac.id/penelitian/Penelitian...   2019
# 9   http://digilib.uad.ac.id/penelitian/Penelitian...   2017
# 10  http://digilib.uad.ac.id/penelitian/Penelitian...   2018
# 11  http://digilib.uad.ac.id/penelitian/Penelitian...   2019
# 12  http://digilib.uad.ac.id/penelitian/Penelitian...   2013
# 13  http://digilib.uad.ac.id/penelitian/Penelitian...   2016
# 14  http://digilib.uad.ac.id/penelitian/Penelitian...   2018
# 15  http://digilib.uad.ac.id/penelitian/Penelitian...   2017
# 16  http://digilib.uad.ac.id/penelitian/Penelitian...   2017
# 17  http://digilib.uad.ac.id/penelitian/Penelitian...   2018
# 18  http://digilib.uad.ac.id/penelitian/Penelitian...   2012
# 19  http://digilib.uad.ac.id/penelitian/Penelitian...   2019
# 20  http://digilib.uad.ac.id/penelitian/Penelitian...   2018
# 21  http://digilib.uad.ac.id/penelitian/Penelitian...   2018
# 22  http://digilib.uad.ac.id/penelitian/Penelitian...   2018
# 23  http://digilib.uad.ac.id/penelitian/Penelitian...   2018
# 24  http://digilib.uad.ac.id/penelitian/Penelitian...   2017
# 25  http://digilib.uad.ac.id/penelitian/Penelitian...   2010
# 26  http://digilib.uad.ac.id/penelitian/Penelitian...   2016
# 27  http://digilib.uad.ac.id/penelitian/Penelitian...   2014
# 28  http://digilib.uad.ac.id/penelitian/Penelitian...   2013
# 29  http://digilib.uad.ac.id/penelitian/Penelitian...   2014
# 30  http://digilib.uad.ac.id/penelitian/Penelitian...   2016
# 31  http://digilib.uad.ac.id/penelitian/Penelitian...   2010
# 32  http://digilib.uad.ac.id/penelitian/Penelitian...   2017
# 33  http://digilib.uad.ac.id/penelitian/Penelitian...   2018
# 34  http://digilib.uad.ac.id/penelitian/Penelitian...   2018
# 35  http://digilib.uad.ac.id/penelitian/Penelitian...   2018
# 36  http://digilib.uad.ac.id/penelitian/Penelitian...   2009
# 37  http://digilib.uad.ac.id/penelitian/Penelitian...   2018
# 38  http://digilib.uad.ac.id/penelitian/Penelitian...   2014
# 39  http://digilib.uad.ac.id/penelitian/Penelitian...   2008
# 40  http://digilib.uad.ac.id/penelitian/Penelitian...   2008
# 41  http://digilib.uad.ac.id/penelitian/Penelitian...   2008
# 42  http://digilib.uad.ac.id/penelitian/Penelitian...   2018
# 43  http://digilib.uad.ac.id/penelitian/Penelitian...   2018

# %%
df.to_excel("dataset_scrapper.xlsx", index=False)
