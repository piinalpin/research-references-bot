# %%
# Load libraries
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from stop_words import get_stop_words
import pandas as pd
import numpy as np 
import string, re
import random

stemmer = StemmerFactory().create_stemmer()
stopwords_id = get_stop_words("id")

def preprocess(text):
    text = text.lower().split(" ")
    text_clean = " ".join([i for i in text if i not in stopwords_id])
    text_stem = stemmer.stem(text_clean)
    result = ''.join([i for i in text_stem if not i.isdigit()])
    result = re.sub(r'[^\x00-\x7f]',r'', result)
    result = re.sub(r'[^\w\s]','',result)
    return result

# %%
query = "tolong dong kasih referensi judul tentang text mining menggunakan manhattan distance similarity"
query = query.partition("tentang")[2].lstrip()
preprocess(query)
# Out:
# 'text mining guna manhattan distance similarity'

# %%
query2 = "tau referensi penelitian"
query2 = query2.partition("tentang")
print(query2)
if "tentang" not in query2:
    print("OK")
else:
    print("HAHA")
# Out:
# ('tau referensi penelitian', '', '')
# OK

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
class Engine(object):
    
    def __init__(self, query):
        self.dataset = pd.read_excel("dataset_sample.xlsx")
        self.phrase = [query] + self.dataset["preprocessed_title"].tolist()
        self.vectorizer = TfidfVectorizer()
        
    def get_scores(self):
        transform = self.vectorizer.fit_transform(self.phrase)
        scores = (transform[0, :] * transform[1:, :].T).A[0]
        self.dataset["score"] = scores
        result = self.dataset.sort_values(by="score", ascending=False).head(10)
        dictionary = {
            "author": result["author"],
            "title": result["title"],
            "url": result["url"],
            "year": result["year"],
            "score": result["score"]
        }
        return dictionary

# %%
test = Engine(query=preprocess(query))
data = test.get_scores()
nn = pd.DataFrame(data)
nn
# Out:
#                     author                                              title  \
# 1         Tsani Elvia Nita  Text Mining Menggunakan Metode Single Linkage ...
# 2                 Nurlaila  Text Mining Menggunakan Metode Snn Dengan Evcl...
# 5       Ika Kurnia Saputri  Penerapan Text Mining Pengelompokkan Judul Ker...
# 7               Ade Antika  Implementasi Text Mining Pengelompokkan Judul ...
# 6           Vega Purwayoga  Pemanfaatan Text Mining Untuk Mengklasifikasi ...
# 10         Anang Marfianto  Analisis Forensik Whats App Mesengger Berbasis...
# 8    Alfin Fajar Nurrahman  Aplikasi Web Dengan Text Mining Untuk Pengelom...
# 3          Nurmulyaningsih  Text Mining Klasifikasi Judul Skripsi Teknik I...
# 11    Taufik Mufti Haryadi  Rancang Bangun Data Mining Untuk Mencari Pola ...
# 17     Aprial Andi Purnama  Penerapan Data Mining Untuk Clustering Status ...
#
#                                                   url  year     score
# 1   http://digilib.uad.ac.id/penelitian/Penelitian...  2018  0.424493
# 2   http://digilib.uad.ac.id/penelitian/Penelitian...  2019  0.243785
# 5   http://digilib.uad.ac.id/penelitian/Penelitian...  2017  0.196898
# 7   http://digilib.uad.ac.id/penelitian/Penelitian...  2019  0.194389
# 6   http://digilib.uad.ac.id/penelitian/Penelitian...  2016  0.084970
# 10  http://digilib.uad.ac.id/penelitian/Penelitian...  2018  0.079571
# 8   http://digilib.uad.ac.id/penelitian/Penelitian...  2016  0.070473
# 3   http://digilib.uad.ac.id/penelitian/Penelitian...  2018  0.062175
# 11  http://digilib.uad.ac.id/penelitian/Penelitian...  2017  0.033592
# 17  http://digilib.uad.ac.id/penelitian/Penelitian...  2018  0.027187

# %%
for i in range(len(data["author"])):
    author = float(list(data["score"])[i])
    print(author)
# Out:
# 0.4244927829605457
# 0.24378495116457477
# 0.19689846279677187
# 0.19438872471548307
# 0.084970049613026
# 0.07957119132083751
# 0.07047333966337858
# 0.0621754640308416
# 0.033591993715763664
# 0.027187116363177433

# %%
dataset = pd.read_excel("dataset_raw.xlsx")

# %%
pre = list()
for x in dataset["title"]:
    pre.append(preprocess(x))

# %%
list(data["author"])[0].lstrip()
# Out:
# 'Tsani Elvia Nita'

# %%
nn.to_string()
# Out:
# '                    author                                              title                                                url  year     score\n1         Tsani Elvia Nita  Text Mining Menggunakan Metode Single Linkage ...  http://digilib.uad.ac.id/penelitian/Penelitian...  2018  0.424493\n2                 Nurlaila  Text Mining Menggunakan Metode Snn Dengan Evcl...  http://digilib.uad.ac.id/penelitian/Penelitian...  2019  0.243785\n5       Ika Kurnia Saputri  Penerapan Text Mining Pengelompokkan Judul Ker...  http://digilib.uad.ac.id/penelitian/Penelitian...  2017  0.196898\n7               Ade Antika  Implementasi Text Mining Pengelompokkan Judul ...  http://digilib.uad.ac.id/penelitian/Penelitian...  2019  0.194389\n6           Vega Purwayoga  Pemanfaatan Text Mining Untuk Mengklasifikasi ...  http://digilib.uad.ac.id/penelitian/Penelitian...  2016  0.084970\n10         Anang Marfianto  Analisis Forensik Whats App Mesengger Berbasis...  http://digilib.uad.ac.id/penelitian/Penelitian...  2018  0.079571\n8    Alfin Fajar Nurrahman  Aplikasi Web Dengan Text Mining Untuk Pengelom...  http://digilib.uad.ac.id/penelitian/Penelitian...  2016  0.070473\n3          Nurmulyaningsih  Text Mining Klasifikasi Judul Skripsi Teknik I...  http://digilib.uad.ac.id/penelitian/Penelitian...  2018  0.062175\n11    Taufik Mufti Haryadi  Rancang Bangun Data Mining Untuk Mencari Pola ...  http://digilib.uad.ac.id/penelitian/Penelitian...  2017  0.033592\n17     Aprial Andi Purnama  Penerapan Data Mining Untuk Clustering Status ...  http://digilib.uad.ac.id/penelitian/Penelitian...  2018  0.027187'

# %%
dataset_pre = pd.read_excel("dataset_raw.xlsx")
for k in dataset_pre.title:
    print(k)
# Out:
# Perancangan Model Supply Chain Management (Scm) Dengan Analisis Balanced Scorecard (Bsc) Pada Pa Dhanar
# Website Update Skor Pertandingan Sepak Bola Liga Indonesia
# Web Service Backend Manajemen Perpustakaan Desa Berbasis Konsep Software As A Service (Saas)
# Visualisasi Teknik Pengobatan Akupuntur Dengan Animasi 3D
# Visualisasi Proses Enkripsi Dan Deskripsi Metode Adfgvx Product Cipher Dan Cipher Block Chaining
# Visualisasi Penanggulangan Bahaya Demam Berdarah
# Visualisasi Materi Kuliah Kimia Perancangan Menara Distilasi Multikomponen
# Visualisasi Erupsi Gunung Berapi Non -Explosive Berbasis 3 D
# Visualisasi Struktur Bangunan Rumah Tahan Gempa Berbasis 3D
# Visualisasi Pembelajaran Algoritma Dijkstra Untuk Mencari Lintasan Terpendek
# Visualisasi Pembangkit Listrik Tenaga Surya (Solar Sel)
# Visualisasi Peletakan Buku Di Perpustakaan Menggunakan Java [Studi Kasus Di Perpustakaan Daerah Yogyakarta]
# Visualisasi Maxinari Residence Dan Penentu Harga Rumah Berdasarkan Satuan Bahan Pada Maxinari Residence Sebagai Media Pemasaran
# Visualisasi Algoritma Cipher Block Chaining Sebagai Media Pembelajaran Berbasis Mobile Android
# Verifikasi Wajah Untuk Sistem Presensi Mahasiswa
# Translator Bahasa Mandarin Indonesia Berbasis Wap
# Theme Generator Cms Wordpress Menggunakan Teknologi Html 5 Untuk Mempermudah Pembuatan Theme Sebagai Media Promosi (Studi Kasus Synchronous, Yogyakarta)
# Test Interest Of Multiple Intelligences Berbasis Web Studi Kasus Sd Juara Yogyakarta
# Teknologi Augmented Reality Untuk Pengembangan Aplikasi Pengenalan Motif Songket Palembang
# The Measuring Of Technology Reception In The Use Ofinformation System Of Regional Library By Using Modeltechnology Acceptence Model (Tam)
# Survei E-Readiness Infrastruktur Perguruan Tinggi Di Yogyakarta Dalam Perkuliahan Berbasis E-Learning
# Solusi Pengobatan Produk K-Link Dengan Sistem Pakar
# Sistem Penggajian Kantor Balai Konservasi Borobudur Berbasis Client-Server
# Sistem Pengenalan Jenis Kayu Menggunakan Principal Components Analysis
# Sistem Pengelolaan Promosi Barang Berbasis Website Menggunakan Metode Analytical Hierarchy Prosess (Studi Kasus Di Magaswalayan Yoyakarta)
# Sistem Pengamanan Distribusi Software Dengan Sms Gateway
# Sistem Penerimaan Siswa Baru Studi Kasus Di Smkn 1 Pringgabaya Lombok Timur Ntb
# Sistem Penentuan Keterkaitan Antar Skripsi Berdasarkan Keyword Seeking (Studi Kasus : Perpustakaan Universitas Ahmad Dahlan)
# Sistem Pendukung Keputusan Untuk Pemilihan Lokasi Pembukaan Cabang Usaha Variasi Mobil Dengan Metode Promethee (Tudi Kasus Pada Usaha Variasi Mobil Anfa)
# Sistem Pendukung Keputusan Untuk Menentukan Supplier Terbaik Menggunakan Metode Weighted Product
# Sistem Pendukung Keputusan Untuk Menentukan Peringkat Sekolah (Sma Kota Yogyakarta) Berbasis Web
# Sistem Pendukung Keputusan Untuk Menentukan Kualitas Jamur
# Sistem Pendukung Keputusan Untuk Menentukan Hama Dan Penyakit Pada Tanaman Holtikultura Komoditas Sayuran Dengan Metode Case Base Reasoning Berbasis Web
# Sistem Pendukung Keputusan Seleksi Calon Karyawan Dengan Metode Promethee ( Studi Kasus Pamella Group Yogyakarta)
# Sistem Pendukung Keputusan Penilaian Kualitas Jenis Kayu Untuk Dijadikan Ukiran Dan Furniture Menggunakan Kriteria Bayea
# Sistem Pendukung Keputusan Penentuan Lokasi Pendirian Counter Handphone Disertai Petunjuk Lokasi Geografisnya Di Kota Yogyakarta
# Sistem Pendukung Keputusan Penentuan Lokasi Budidaya Jamur Tiram Dengan Metode Kriteria Bayes
# Sistem Pendukung Keputusan Penentuan Kesesuaian Jenis Lahan Untuk Budidaya Tanaman Buah-Buahan Menggunakan Metode Similarity Berbasis Web
# Sistem Pendukung Keputusan Penentuan Daerah Pencemaran Limbah Home Industri Berbasis Sig
# Sistem Pendukung Keputusan Penentuan Daerah Demam Berdarah Dengue (Dbd) Di Provinsi Daerah Istimewa Yogyakarta Menggunakan Kriteria Bayes
# Sistem Pendukung Keputusan Penentuan Calon Petugas Haji Dengan Metode Simple Additive Weighthing
# Sistem Pendukung Keputusan Pemilihan Lokasi Warnet Dengan Metode Ahp (Studi Kasus : Green Net)
# Sistem Pendukung Keputusan Menentukan Pekerjaan Berdasarkan Tes Kepribadian Berbasis Web
# Sistem Pendukung Keputusan Klinis Untuk Mengefisienkan Diagnosa Penyakit Kejiwaan Menggunakan Case Based Reasonning
# Sistem Pencarian Lokasi Lampu Lalu Lintas Pt.Qumicom Indonesia Berbasis Web
# Sistem Penalaran Berbasis Kasus Untuk Mendiagnosa Penyakit Gigi Dan Mulut
# Sistem Pembelajaran Interaktif Dengan Materi Pokok Lensa Berbasis Multi Media Untuk Siswa Sma Kelas Xi
# Sistem Pakar Untuk Menentukan Pertolongan Pertama Pada Kecelakaan Berbasis Mobile
# Sistem Pakar Untuk Mendiagnosis Penyakit Pada Kasus Bedah Umum Dengan Menggunakan Metode Dempster-Shafer
# Sistem Pakar Untuk Mendiagnosa Penyakit Pada Tanaman Pangan Menggunakan Certainty Factor
# Sistem Pakar Untuk Mendiagnosa Penyakit Menular Dari Hewan Ke Manusia (Zoonosis) Menggunakan Metode Demste Shafer
# Sistem Pakar Untuk Mendiagnosa Penyakit Kambing Etawa Berbasis Web
# Sistem Pakar Pendeteksian Dini Penyakit Kelamin Berbasis Wireles Application Protocol Dengan Teorema Bayes
# Sistem Pakar Menentukan Hama Dan Penyakit Pada Tanaman Palawija
# Sistem Pakar Mendiagnosa Kerusakan Pada Sepeda Motor Menggunakan Metode Teorema Bayes
# Sistem Pakar Berbasis Web Untuk Diagnosa Penyakit Pada Sapi
# Sistem Otentikasi User Dalam Jaringan Wireles Berbasis Web Pada Server Linux
# Sistem Konsultasi Keuangan Dalam Menentukan Penerimaan Pinjaman Di Lkm (Lembaga Keuangan Mikro) Menggunakan Metode K-Neares Neighbor
# Sistem Integrasi Data Untuk Mempermudah Pertukaran Informasi Obat Antar Klinik Kesehatan Berbasis Web Service
# Sistem Identifikasi Citra Rimpang Pada Tanaman Famili Zingiberaceae (Temu-Temuan) Menggunakan Metode Fungsi Jarak One Minus Correlation Coefficient
# Sistem Diagnosa Tumbuh Kembang Anak Dengan Representasi Pengetahuan Jaringan Semantik
# Sistem Riwayat Kompetensi Mahasiswa Berbasis Web Service (Studi Kasus Program Studi Teknik Informatika)
# Sistem Penentuan Perencanaan Pelaksanaan Program Imunisasi Yang Disertai Peta Geografisnya (Sudi Kasus Dinas Kesehatan Kab. Wonosobo)
# Sistem Penentuan Mahasiswa Berprestasi Pada Lingkungan Kopertis V Dengan Metode Kriteria Bayes Berbasis Multi User
# Sistem Pendukung Keputusan Seleksi Penerimaan Beras Untuk Keluarga Miskin Menggunakan Metode Simple Additive Weighting
# Sistem Pendukung Keputusan Untuk Menentukan Diagnosis Penyakit Hewan Ternak Menggunakan Metode Case Base Reasoning
# Sistem Pendukung Keputusan Untuk Melacak Kecenderungan Bakat Pada Anak
# Sistem Pendukung Keputusan Peramalan Permintaan Geplak Menggunakan Metode Exponential Smoothing Studi Kasus Pabrik Geplak Cinta Rasa Dusun Tirto Triharjo Pandak
# Sistem Pendukung Keputusan Penyeleksian Posisi Pemain Dalam Sepak Bola (Studi Kasus Klub Bola Ps Kalasan)
# Sistem Pendukung Keputusan Penentuan Status Gizi Balita
# Sistem Pendukung Keputusan Penentuan Posisi Pemain Pada Olahraga Bola Voli
# Sistem Pendukung Keputusan Penentuan Penerima Jaminan Kesehatan Masyarakat Untuk Masyarakat Miskin Menggunakan Kriteria Bayes (Studi Kasus Dinas Kesehatan Kabupaten Kulon Progo)
# Sistem Pendukung Keputusan Penentuan Penerima Beasiswa Di Sekolah Menengah Pertama (Smp) Menggunakan Kriteria Bayes (Studi Kasus Smp Negeri 2 Pandak Bantul)
# Sistem Pendukung Keputusan Penentuan Lokasi Bts Menggunakan Metode Bayes
# Sistem Pendukung Keputusan Penentuan Kualitas Sdm Karyawan Pt. Madu Baru Yogyakarta
# Sistem Pendukung Keputusan Penentuan Kualitas Kayu Untuk Kerajinan Meubel
# Sistem Pendukung Keputusan Penentuan Kualitas Jenis Kulit Hewan Untuk Kerajinan Kulit Dengan Pendekatan Sistem Pakar
# Sistem Pendukung Keputusan Penentuan Kelayakan Lokasi Pendirian Klinik
# Sistem Pendukung Keputusan Penentuan Kelayakan Bus Kota Berbasis Web Dengan Kriteria Bayes
# Sistem Pendukung Keputusan Penempatan Tenaga Kesehatan
# Sistem Pendukung Keputusan Pemilihan Lokasi Untuk Kawasan Perumahan Di Kabupaten Bantul Yogyakarta Berbasis Web
# Sistem Pendukung Keputusan Pemilihan Guru Berprestasi Tingkat Sma Di Kota Yogyakarta Menggunakan Kriteria Bayes Berbasis Client Server
# Sistem Pendukung Keputusan Pemilihan Bidang Minat Mahasiswa Teknik Informatika Dengan Metode Profile Matching Berbasis Web
# Sistem Pendukung Keputusan Klinis Untuk Diagnosa Penyakit Kandungan Berbasis Case Base Reasoning Dengan Pendekatan Sistem Pakar
# Sistem Pendukung Keputusan Kesehatan Untuk Penderita Penyalit Diabetes Mellitus Dan Komplikasinya Berbasis Wap (Wireless Application Protocol)
# Sistem Pendukung Keputusan Dengan Pemetaan Untuk Meningkatkan Ekonomi Berbasis Industri Kecil
# Sistem Pendukung Keputusan Dalam Penilaian Kinerja Pegawai Untuk Kenaikan Jabatan Menggunakan Metode Gap Kompetensi
# Sistem Pendukung Keputusan Dalam Pemilihan Lokasi Bengkel Dengan Metode Promethee
# Sistem Pendukung Keputusan Barang Layak Promosi Pada Minimarket (Studi Kasus Pamella Swalayan Yogyakarta)
# Sistem Pendeteksi Penyakit Pada Ikan Gurame Menggunakan Jaringan Syaraf Tiruan Dengan Metode Backpropagation
# Sistem Pendaftaran Layanan Kesehatan Dokter Praktek Berbasis Sms Gateway
# Sistem Pencarian Jalur Terpendek Trayek Bus Transjogja
# Sistem Penalaran Berbasis Kasus Untuk Penyakit Yang Ditularkan Oleh Nyamuk
# Sistem Pemesanan Tiket Pertandingan Sepak Bola Berbasis Short Messages Services
# Sistem Pemesanan Taksi Menggunakan Layanan Berbasis Lokasi
# Sistem Pemantauan Ditribusi Persediaan Barang Berbasis Intraweb Di Cv. Citra Putra Mandiri Lampung
# Sistem Pelacak Kendaraan Berbasis Opengts Di Pt. Panji Sekar Yogyakarta
# Sistem Pakar Untuk Mendiagnosa Penyakit Lambung Dengan Implementasi Metode Cbr (Case-Based Reasoning) Berbasis Web
# Sistem Pakar Dalam Menentukan Jenis Perawatan Wajah(Studi Kasus Rs Pku Muh Yogyakarta)
# Sistem Pakar Untuk Mengidentifikasi Penyakit Udang Galah Dengan Metode Theorema Bayes
# Sistem Pakar Untuk Mendiagnosis Penyakit Gangguan Tidur Berbasis Web Menggunakan Metode Certainty Factor
# Sistem Pakar Untuk Mendiagnosis Kerusakan Pada Kamera Digital
# Sistem Pakar Untuk Mendiagnosa Penyakit Saluran Pernafasan Dan Paru Menggunakan Metode Certainty Factor
# Sistem Pakar Untuk Mendiagnosa Penyakit Saluran Pencernaan Menggunakan Metode Dempster Shafer
# Sistem Pakar Untuk Mendiagnosa Penyakit Pada Usus Manusia Menggunakan Metode Case Based Reasoning
# Sistem Pakar Untuk Mendiagnosa Penyakit Pada Tanaman Serealia
# Sistem Pakar Untuk Mendiagnosa Penyakit Pada Tanaman Palawija Berbasis Web
# Sistem Pakar Untuk Mendiagnosa Penyakit Pada Tanaman Jamur Dengan Metode Certainty Factor
# Sistem Pakar Untuk Mendiagnosa Penyakit Pada Kelinci Dengan Metode Certainty Factor
# Sistem Pakar Untuk Mendiagnosa Penyakit Pada Ikan Hias Berbasis Web
# Sistem Pakar Untuk Mendiagnosa Penyakit Pada Hewan Mamalia
# Sistem Pakar Untuk Mendiagnosa Penyakit Lambung Menggunakan Metode Teorema Bayes
# Sistem Pakar Untuk Mendiagnosa Penyakit Kelinci Berbasis Web
# Sistem Pakar Untuk Mendiagnosa Hama Dan Penyakit Tanaman Bawang Merah Menggunakan Certainty Factor
# Sistem Pakar Untuk Identifikasi Penyakit Umum Berbasis Web
# Sistem Pakar Untuk Diagnosa Penyakit Yang Ditularkan Dari Hewan Lalat Kepada Manusia Berbasis Web Dengan Metode Theorema Bayes
# Sistem Pakar Penentuan Obat Antihipertensi Bagi Penderita Penyakit Komplikasi Dengan Metode Dempster Shafer
# Sistem Pakar Penentuan Kesesuaian Lahan Pertanian Untuk Pembudidayaan Tanaman Buah-Buahan
# Sistem Pakar Mendiagnosa Penyakit Pada Ikan Air Tawar Berbasis Website
# Sistem Pakar Mendiagnosa Penyakit Pada Buah-Buahan Pasca Panen
# Sistem Pakar Mendiagnosa Jenis Penyakit Stroke Menggunakan Metode Certainty Factor
# Sistem Pakar Diagnosa Penyakit Skizofrenia Menggunakan Metode Demspter-Shafer Berbasis Web
# Sistem Pakar Diagnosa Penyakit Pernapasan Pada Manusia Berbasis Web Dengan Metode Tsukamoto
# Sistem Pakar Diagnosa Penyakit Kanker Dengan Penerapan Dempster-Shafer Teori
# Sistem Pakar Diagnosa Kelainan Pertumbuhan Pada Bayi Semasa Dalam Kandungan
# Sistem Pakar Berbasis Web Untuk Mendiagnosa Penyakit Unggas Menggunakan Teorema Bayes
# Sistem Monitoring Pemecahan Masalah Bimbingan Konseling Siswa Pada Mts N Gubuk Rubuh Wonosari
# Sistem Laboratorium Sdit Luqman Al Hakim Yogyakarta Menggunakan Analisis Zachman Framework
# Sistem Konsultasi Diagnosa Kerusakan Dan Modifikasi Sepeda Motor Matic
# Sistem Identifikasi Citra Jahe (Zingiber Officinale) Menggunakan Metode Jarak Czekanowski
# Sistem Broadcase Proses Belajar Mengajar Dengan Synchronous Dan Asynchronous
# Sistem Administrasi Penghunian Kost Di Wilayah (Studi Kasus Rw 04 Janturan, Umbulharjo, Yogyakarta
# Simulasi Pemilihan Rute Terpendek Dengan Algoritma Djikstra Menggunakan Macromedia Flash Mx
# Simulasi Proses Enkripsi Dan Dekripsi Algoritma Rijndael Untuk Mendukung Proses Pembelajaran Kriptografi Berbasis Web
# Simulasi Pembayaran Tiket Pertandingan Sepak Bola Berbasis Wap
# Segmentasi Citra Medik Mri (Magnetic Resonance Imaging) Menggunakan Metode Region Threshold
# Segmentasi Citra Kanker Serviks Menggunakan Metode K-Means Clustering Dan Region Growing
# Spk Pemilihan Lokasi Pabrik Dengan Metode Brown-Gibson
# Sistem Resevasi Hotel Berbasisi Mobile Aplication Dengan Menggunakan Java Midlet Dan Mysql
# Sistem Pengolahan Aset Desa Dan Administrasi Desa Berbasis Web
# Sistem Pendukung Keputusan Penentuan Lokasipembangunan Tower Base Transceiver Station (Bts)Menggunakan Kriteria Bayes Yang Disertai Dengan Letakgeografisnya
# Sistem Pendukung Keputusan Pemilihan Program Studi Bagi Mahasiswa Baru Universitas Ahmad Dahlan Yogyakarta Menggunakan Metode Topsis
# Sistem Pendukung Keputusan Dalam Menentukan Pemenang Jasa Pemborong Proyek Dengan Metode Kriteria Bayes(Studi Kasus: Dinas Pekerjaan Umum Kabupaten Temanggung)
# Sistem Pakar Untuk Diagnosa Komplikasi Pada Ibu Dan Janindimasa Kehamilan Berbasis Mobile
# Sistem Pakar Berbasis Web Untuk Mengidentifikasi Penyakit Pada Hewan Peliharaan
# Segmentasi Citra Batik Sasambo Berdasarkan Fitur Tekstur Menggunakan Metode Filter Gabor Dan Mean Shift Clustering
# Rekayasa Aplikasi Pengolahan Data Barang Berbasiska Basis Data Di Pt Indomarco Adi Prima Tasikmalaya
# Rancangn Bangun Sig Pemantauan Penyebaran Penyakit Dbd Kabupaten Siak Berbasis Web
# Rancang Bangun Sistem Pakar Untuk Mendiagnosa Kerusakan Mesin Kapal Laut
# Rancang Bangun Sistem Monitoring Terapi Arv (Antiretroviral) Dengan Metode Client Server Berbasis Smartphone Pada Rsup Dr. Sardjito
# Rancang Bangun Aplikasi Marketplace Restoran Di Yogyakarta Berbasis Web Online
# Rancang Bangun Aplikasi Enkripsi Dan Dekripsi Sms(Short Message Service) Pada Mobile Dengan Algoritma Adfgvx Aproduct Cipher Berbasis J2Me)
# Rancang Bangun Sistem Pendukung Keputusan Penentuan Urutan Personil Haji/Umroh Dengan Biaya Dinas (Studi Kasus: Universitas Ahmad Dahlan (Uad))
# Rancang Bangun Web Sistem Pengelolaan Zakat Berbasis Rich Internet Application
# Rancang Bangun Web Service Aplikasi Management Event (Acara)
# Rancang Bangun Visualisasi Model Tiga-Dimensi Tata Surya Berbasis Teknologi Augmented Reality
# Rancang Bangun Ui (User Interface) /Ux (User Experience ) Aplikasi Manajemenâ  Skripsi Pada Program Studi Teknik Informatika Uad
# Rancang Bangun Sistem Pendukung Keputusan Dalam Penempatan Guru Wali Kelas Berbasis Kasus
# Rancang Bangun Sistem Layanan Berbasis Lokasi Untuk Mobile Marketing Produk Usaha Mikro Kecil Dan Menengah (Umkm) Dengan Pemanfaatan Konsep Intelligent Resource Monitor (Irm)
# Rancang Bangun Sistem Hotspot Menggunakan Captive Portal
# Rancang Bangun Pemodelan Secret Sharing Dengan Menggunakan Kriptografi Cipher Block Chaining
# Rancang Bangun Digital Library Multiserver Dengan Teknologi Web Service
# Rancang Bangun Aplikasi Website E-Commerce Desain Interior Dan Eksterior Pada Cv. Graha Anggun Abadi
# Rancang Bangun Aplikasi Web Untuk Membantu Proses Belajar Mahasiswa Teknik Informatika Uad Pada Matakuliah Matematika Diskret Materi Kombinatorik
# Rancang Bangun Aplikasi Traffic Counter Memanfaatkan Radio Frequency Identification(Rfid)
# Rancang Bangun Aplikasi Model Kuesioner Penilaian Aktivitas Pengajaran Dosen Oleh Mahasiswa
# Rancang Bangun Aplikasi Mobile Chat Room Menggunakan Koneksi Bluetooth
# Rancang Bangun Aplikasi Game Dam Daman Guna Melestarikan Permainan Tradisional
# Rancang Bangun Aplikasi Business Intelligence Uji Kinerja Unit Menggunakan Metode Balanced Scorecard (Studi Kasus: Bagian Antaran Mail Processing Center Pt. Pos Indonesia Semarang)
# Rancang Bangun Aplikasi Android Specialist Interest Group (Sig) Di Teknik Informatika Universitas Ahmad Dahlan Yogyakarta Dengan Menggunakan Metode Google Google Cloud Messaging
# Rancang Bangun Metode Kriptografi Hybrid Untuk Pengamanan Dokumen Digital
# Prototype Internet Radio Broadcasting
# Proses Dan Dampak Keberhasilan Seo Onpage Offpage Terhadap Pagerank, Index Dan Visitor Untuk Fresh Website
# Program Bantu Belajar Bangun-Bangun Geomatri Pada Siswa Sd
# Prediksi Konsumsi Listrik Pada Ikm Winner Glove Menggunakan Metode Backpropagation
# Prediksi Lama Studi Mahasiswa S1 Teknik Informatika Universitas Ahmad Dahlan Berdasarkan Prestasi Akademik Menggunakan Metode Native Bayes
# Perbedaan Problem Focused Coping Dalam Menghadapi Tugas Kuliah Ditinjau Dari Jenis Kelamin Pada Mahasiswa Jurusan Teknik Informatika Uad Yogyakarta
# Perbedaan Sikap Pemecahan Masalah Antara Mahasiswa Prodi Psikologi Dengan Mahasiswa Prodi Teknik Informatika Universitas Ahmad Dahlan Yogyakarta
# Perbandingan Metodologi Web Application Frame Work (Cake Php,Codeigniter Dan Yii)
# Perbandingan Metode Inner Product Dan Cosine Similarity Dalam Pembuatan Sistem Identifikasi Citra Jenis Rosella
# Perangkat Lunak Bantu Untuk Pembelajaran Pengenalan Pahlawan Indonesia Untuk Anak Sekolah Dasar
# Perangkat Lunak Bantu Pembelajaran Pengenalan Satwa Indonesia Untuk Anak Sekolah Dasar
# Perancangan Sistem Pendukung Keputusan Penentuan Rumah Sehat
# Perancangan Prototipe Aplikasi Sistem Pakar Mendiagnosa Penyakit Pada Tanaman Pertanian Organik Berbasis Web Dengan Metode Bayes
# Perancangan Program Pembelajaran Daar-Dasar Fotografi Menggunakan E-Learning
# Perancangan Perangkat Lunak Pembelajaran Struktur Data Pohon Ekspresi (Expression Tree) (Studi Kasus Di Universitas Ahmad Dahlan Yogyakarta)
# Perancangan Enterprise Architecture Dengan Kerangka Kerja Zachman Di Kantor Wilayah Kementerian Agama Diy
# Perancangan Dan Implementasi Film Animasi 3D Sholihuun Berbasis Software Open Source
# Perancangan Dan Implementasi Dengan Topik Latihan Penyusunan Paraagraf Bahasa Indonesia Untuk Sdkelas V (Studi Kasus Sdit Lukman Alhakim)
# Perancangan Dan Implementasi Bahasa Pemrograman Algoena Menggunakan Notasi Algoritma
# Perancangan Sistem Pakar Untuk Mendeteksi Hama Dan Penyakit Pada Tanaman Cengkeh Berbasis Website
# Perancangan Sistem Monitoring Bandwidth Internet Berbasis Sms
# Perancangan Model Tata Kelola Teknologi Informasi Xyz Indonesia Berbasis Cobit 4.1
# Perancangan Model Tata Kelola Teknologi Informasi Berbasis Cobit 4.1 Pada Proses Pengelolaan Sumber Daya Manusia It (Studi Kasus Bagian Pengelolaan Data Kab. Kendal)
# Perancangan Model Enterprise Resource Planning (Erp)Studi Kasus Pt. Madubaru
# Perancangan Enterprise Resource Planning Badan Keuangan Dan Akuntansi Pt. Xyz
# Perancangan Enterprise Architecture Planning (Eap) Pada Proses Manajemen Aset Dengan Zachman Framework (Studi Kasus Divisi Manajemen Fasilitas Pt. Xyz)
# Perancangan E-Mall Sebagai Media Informasi Dan Pembelian Buku Berbasis Wap
# Perancangan E-Library Pada Perpustakaan Di Sekolah Dasar Untuk Menyediakan Referensi Belajar Siswa Menggunakan Web Service
# Perancangan Dan Implementassi Metode Pembelajaran Kriptografi Md5 [Message Digest 5]
# Perancangan Dan Implementasi Web E-Commerce Pemesanan Dan Penjualan Fashion Pada Bali Island
# Perancangan Dan Implementasi Sistem Pembelajaran Bahasa Indonesia Dengan Topik Kata Imbuhan Untuk Sd Kelas V (Studi Kasus Sdit Lukman Al Hakim Yogyakarta
# Perancangan Dan Implementasi Pembelajaran Perkalian Dan Pembagian Bilangan Untuk Sekolah Dasar Kelas 2 (Studi Kasus Sd It Lukman Al Hakim Yogyakarta)
# Perancangan Dan Implementasi M-Sev (Manager System Electronic Voucher) Software Aplikasi Pengisian Pulsa Elektrik Dengan Object Oriented Development
# Perancangan Aplikasi Kontruksi Dinding Penahan Tanah Jenis Dinding Grafitasi Atau Gravity Wall
# Perancang Dan Implementasi Sekuriti Sistem E-Mpney Pada Infrastruktur Sms Over Gprs
# Peningkatan Mutu Kontras (Intensitas) Citra Digital Menggunakan Gabungan Teknik Pergeseran Dan Teknik Pelebaran Histogram
# Pengukuran Kinerja Penyelesaian Sistem Persamaan Linier Menggunakan Metode Eliminasi Gauss,Gauss-Jordan,Matriks Invens Dan Dekomposisi Lu)
# Pengukuran E-Readiness Dosen Universitas Ahmad Dahlan Dalam Perkuliahan Berbasis E-Learning
# Pengukuran E-Readiness Mahasiswa Pada Penerapan E-Learning Uad Yogyakarta
# Pengukuran E-Readiness Mahasiswa Yogyakarta Dalam Perkuliahan Berbasis E-Learning
# Pengukuran E-Readiness Dosen Yokyakarta Dalam Perkuliahan Berbasis E-Learning
# Pengingat Otomatis (Aotomatic Reminder) Berbasis Sms Untuk Nasabah Pada Perusahaan Pegasaian
# Penggunaan Aplikasi Sms Untuk Manajemen Inventory Perusahaanstudi Kasus Cv Gunung Jati Distributor Keramik Wilayah Jawa Tengah
# Penggunaan Algoritma Asosiasi Apriori Untuk Mencari Hubungan Keaktifan, Kelulusan, Dan Karir Mahasiswa
# Pengembangan Web Service Dan Oauth 2.0 Pada Web Portal (Studi Kasus Modul Kerja Praktik Pada Portal Program Studi Teknik Informatika Universitas Ahmad Dahlan)
# Pengembangan User Experience Website Design Menggunakan Kansei Engineering Dengan Teknologi Flat And Adaptive Pada Clothing Store Untuk Meningkatkan Kemudahan Dan Kenyamanan Pengguna
# Pengembangan Sistem Penentuan Jabatan Struktural Dan Penempatan Wali Kelas Pada Smk Batur Jaya 1 Ceper Klaten
# Pengembangan Modul Enkripsi Dan Deskripsi Pada Pemrograman Php Dengan Metode Cbc Termodifikasi
# Pengembangan Media Konsultasi Diagnosa Penyakit Ginjal Dan Saluran Kemih Dengan Memanfaatkan Metode Teorema Bayes Berbasis Web
# Pengembangan Komponen Ocx Untuk Pembuatan Label Barcode Menggunakan Metode Code -39 Pada Suatu Aplikasi
# Pengembangan Aplikasi Sistem Pakar Mendiagnosa Penyakit Pada Hewan Peliharaan Berbasis Mobile
# Pengembangan Aplikasi Jaringan Saraf Tiruan Dalam Mendiagnosa Penyakit Epilepsi Dengan Metode Hebb Rule Dan Delta Rule
# Pengembangan Aplikasi Generator Modul Pada Cms Lokomedia Untuk Mempermudah Pengembangan Sistem Berbasis Web
# Pengembangan Animasi Penyuluhan Siaga Bencana Gempa Bumi Menggunakan Metode Frame By Frame Dan Tweening
# Pengembangan Website Aditv Dengan Metode Embed Video Menggunakan Teknologi Html5
# Pengembangan Sistem Perpustakaan Online Sekolah Muhammadiyah Di Yogyakarta Berbasis Web Service
# Pengembangan Sistem Pendukung Keputusan Untuk Kelanjutan Kontrak Kerja Karyawan Percetakan (Studi Kasus Percetakan Muhammadiyah Surya Sarana Grafika)
# Pengembangan Sistem Pakar Troubleshooting Komputer Berbasis Web
# Pengembangan Sistem Komplain Berbasis Web
# Pengembangan Sistem Inventarisasi Seni Dan Budaya Pada Pengurus Pusat Muhammadiyah
# Pengembangan Sistem Administrasi Sekolah Berbasis Web Studi Kasus: Sma Taman Madya Ibu Pawiyatan Tamansiswa Yogyakarta
# Pengembangan Modul Php Barcode Generator
# Pengembangan Modul Enkripsi Dan Dekripsi Pada Php Dengan Modifikasi Metode Kriptografi Cipher Block Chaining Dengan Vigenere Cipher (Implementasi Kasus Pada Geekybyte.Com
# Pengembangan Media Pembelajaran Penggunaan Tanda Baca Pada Siswa Kelas V Sd It Luqman Al Hakim
# Pengembangan Kualitas Layanan Website Dengan Menggunakan Metode Analisis Webqual 4.0
# Pengembangan Game Susun Angka Untuk Menjembatani Anak Usia Dini Belajar Berhitung Di Tk Tat Twam Asi
# Pengembangan Dan Implementasi Algoritma Cipher Block Chaining Dengan Row Transposition
# Pengembangan Aplikasi Sistem Pengukuran Compeency Level Index Berbasis Web (Studi Kasus: Perum Perhutani Kantor Unit Iii)
# Pengembangan Aplikasi Sistem Pakar Untuk Diagnosa Penyakit Anak Menggunakan Metode Dempster Shafer Berbasis Web
# Pengembangan Aplikasi Mobile Web Percakapan Bahasa Korea Berbasis Lokasi Menggunakan Foursquare Api
# Pengembangan Aplikasi Metopen Berbasis Web Pada Program Studi Teknik Informatika Universitas Ahmad Dahlan
# Pengembangan Aplikasi Lagidimana Berbasis Android
# Pengembangan Antivirus Berbasis Local Area Network (Lan) Server
# Pengambangan Perangkat Lunak Bantu Pencarian Ruang Keadaan Dan Penyelesaian Masalah Dengan Pendekatan Kecerdasan Buatan
# Pengamanan Database Mysql Pada Web Dari Serangan Sql Injection
# Penerjemah Bahasa Indonesia -Melayu Rokan Dan Sebaliknya Dilengkapi Dengan Pemeriksa Kalimat Ambigu Berbasis Web
# Penerapan Web Service Untuk Sistem Penilaian Kuliah Kerja Nyata Universitas Ahmad Dahlan
# Penerapan Sistem Keamanan Honeypot Dan Ids Pada Jaringan Nirkabel (Hotspot)
# Penerapan Olap( Online Analytical Process) Pada Pasien Rawat Jalan Rumah Sakit (Tudi Kasus Rskaia Pku Muhamadiyah Kotagede Yogyakarta
# Pemetaan Fasilitas Umum Sarana Kesehatan Kota Yogyakarta Menggunakan Google Maps Api
# Pembutan Model Crm (Customer Relationship Management) Pada Xt Square Yogyakarta
# Pembuatan Perencanaan Arsitektur Enterprise Pada Badan Kerjasama Dan Penanaman Modal (Bkpm) Propinsi Diy Berbasis Soa (Service Oriented Architecture)
# Pembuatan Model Tata Kelola Ti Bidang Layanan Haji Pada Kantor Kementerian Agama Kota Yogyakarta Berbasis Cobit 4.1
# Pembuatan Model Supply Shain Management Pada Cv. Artha Wibisono
# Pembuatan Model Rencana Strategis Pengembangan E-Coverment(Studi Kasus : Dinas Kelautan Dan Perikanan Diy)
# Pembuatan Model Rencana Strategis Si/Ti Bidang Penyelenggaraan Haji Dan Umrah Kantor Wilayah Kementerian Agama Daerah Istimewa Yogyakarta
# Pembuatan Model Rencana Strategi Pengembangan Si/Ti Rumah Sakit Dengan Zachman Framework (Studi Kasus : Rumah Sakit Umum Daerah Wonosari)
# Pembuatan Model Pelayanan (Service) Akademik Pada Mahasiswa Menggunakan Kerangka Manajemen Layanan Itil V.3 Di Universitas Ahmad Dahlan
# Pembuatan Model Enterprise Resource Planning Pada Kantor Dinas Ketahanan Pangan Kabupaten Klaten
# Pembuatan Model Customer Relatioship Management (Crm) E- Government Di Kominfo Diy
# Pembuatan Model Customer Relationship Management (Crm) Pada Donq Donuts
# Pembuatan Model Customer Relation Management (Crm) Pada Pt Naturindo Fresh
# Pembuatan Model Si/Ti Pada Penerbit Buku Amara Books Menggunakan Kerangka Kerja Zachman
# Pembuatan Model Crm(Customer Relationship Management) Pada Bagian Perhubungan Di Dishubkominfo Diy
# Pembuatan Enterprise Architecture Planning Dengan Menggunakan Kerangka Kerja Zachman(Studi Kkasus : Impinan Pusat Muhammadiyah
# Pembuatan Enterprise Architecture Planning Dengan Kerangka Kerja Zachman Di Koperasi Mahasiswa Uad Yogyakarta
# Pembuatan Enterprise Architecture Planning Dinas Kebudayaan Provinsi Diy Dengan Menggunakan Kerangka Zachman
# Pembuatan Action Plan Pengembangan E-Government Dishubkominfo
# Pembuatan Transliterator Aksara Jawa Menggunakan Ibus Input Framework Dan Ekspresi Reguler
# Pembuatan Program Aplikasi Transliterator Teks Berbahasa Jepang Dari Huruf Latin Menjadi Japanese Kana (Hiragana Dan Katakana)
# Pembuatan Perencanaan Arsitektur Enterprise Teknologi Informasi Pada Lembaga Pelatihan Dan Pengembangan Softskill Dengan Metode Zachman Framework (Studi Kasus: Universitas Xyz)
# Pembuatan Model Tata Kelola It Untuk Proses Akademik Menggunakan Cobit 4.1 Studi Kasus : Universitas Xyz
# Pembuatan Model Sistem M-Government (Studi Kasus : Pemerintah Kota Yogyakarta)
# Pembuatan Model Sistem Enterprise Resource Planning Pada Panti Sosial Pamardi Putra Provinsi Diy
# Pembuatan Model Si/Ti Dengan Cobit 4,1 Dan Kerangka Kerja Zachman Di Kantor Ketahanan Pangan Kab.Klaten
# Pembuatan Model Rencana Strategis Si/Ti Di Homestay Venezia
# Pembuatan Model Rencana Strategis Si/Ti (Studi Kasus: Departemen Akademik Universitas Xyz)
# Pembuatan Model Manajemen Perubahan Pada Pengembangan E-Government Menggunakan Teori Technology Acceptance Model (Tam) (Studi Kasus Dinas Perindagkop Provinsi Diy)
# Pembuatan Model Manajemen Perubahan Pada Pengembangan E-Government Dinas Pertanian Provinsi Diy
# Pembuatan Model Enterprise Resource Planning Pada Dinas Kesehatan Provinsi Diy
# Pembuatan Model Enterprise Architecture Planning Btn Surya Umbulharjo Dengan Togaf Architecture Development Method (Bagian Penghimpunan Dan Pembiayaan
# Pembuatan Model Customer Relationship Management [Crm] E-Government Di Dinas Kelautan Dan Perikanan Diy
# Pembuatan Model Customer Relationship Management (Crm) Di Dinas Perindustrian Perdagangan Koperasi Dan Usaha Kecil Menengah (Studi Kasus Dinas Perindakop Provinsi Diy)
# Pembuatan Model Customer Relationship Management (Crm) Dinas Kesehatan Kota Yogyakarta
# Pembuatan Model Customer Relationship Management (Crm) Dinas Kesehatan Diy Menggunakan Delivery And Support (Ds)
# Pembuatan Game Edukatif Tata Tertib Lalu Lintas Untuk Anak Usia Dini
# Pembuatan Enterprise Arsitecture Planning Menggunakan Kerangka Zachman Di Majelis Pustaka Dan Informasi Pp Muhammadiyah Yogyakarta
# Pembuatan Enterprise Architecture Planning Dengan Kerangka Kerja Zachman Di Majelis Pendidikan Tinggi Pp Muhammadiyah Yogyakarta
# Pembuatan Enterprise Architecture Planning (Eap) Di Lembaga Penanggulangan Bencana Pimpinan Pusat Muhammadiyah Yogyakarta Dengan Menggunakan Kerangka Kerja Zachman
# Pembuatan Enterprise Architectur Planning Di Kantor Universitas Dan Urusan Internasional Dengan Kerangka Kerja Zachman
# Pembuatan E Commerce Templates Sebagai Media Informasi Dan Pemasaran Studi Kasus Seagara Itc Distributor
# Pembuatan Aplikasi Transliterator Dan Translator Berbahasa Batak
# Pembuatan Aplikasi Supply Chain Management Berbasis Web Service Untuk Membantu Distribusi Batik Menggunakan Php Dan Mysql
# Pembuatan Aplikasi Bacaan Shalat Wajib Dan Doa Setelah Shalat Dengan Teknik On Over Mouse
# Pembelajaran Metode Kriptografi Block Transposition Dan Row Trasposition Berbasis Web
# Pembangunan Pusat Informasi Obat Untuk Mempermudah Pencarian Data Obat Bagi Masyarakat Berbasis Information Retrieval
# Pembangunan Web Proxy Dengan Mikrotik Untuk Mendukung Internet Sehat Di Smk Muhammadiyah 1 Patuk Gunungkidul
# Pembangunan Web Monitoring Cbt Dengan Menggunakan Sistem Basis Data Terdistribusi Pada Sistem Computer Based Test Ukdgi (Ujian Kompetensi Dokter Gigi Indonesia)
# Pembangunan Sistem Pencarian Lokasi Dengan Geolocation Berdasarkan Gps Berbasis Mobile Web (Studi Kasus Pencarian Lokasi Hotel Di Yogyakarta)
# Pembangunan Sistem Pencarian Lokasi Kuliner Di Yogyakarta Dengan Geolocation Berdasarkan Gps Berbasis Mobile Web
# Pembangunan Online Shop Menggunakan J2Ee (Studi Kasus : Pada Toko Karya Cipta Furniture Jepara)
# Pemanfaatan Webcam Sebagai Sistem Pemantauan Ruangan Kuliah Berbasis Web (Studi Kasus Di Uad Yogyakarta)
# Pemanfaatan Teknik Tweening Dan Character Library Pada Pembuatan Film Animasi Pendek Indahnya Perbedaan Dalam Berteman
# Perbedaan Motivasi Menyelesaikan Skripsi Antara Mahasiswa Yang Bekerja Dengan Mahasiswa Yang Tidak Bekerja Pada Mahasiswa Jurusan Teknik Informatika Universitas Ahmad Dahlan
# Perancangan Model Si/Ti Dengan Pendekatan Supply Chain Management Pada Cv Alas Djogja
# Perancangan Dan Analisis Vpn (Virtual Private Network) Menggunakan L2Tp (Layer 2 Tunneling Protocol) / Ipsec (Ip Security) Pada Kantor Pemasaran Bpjs Kesehatan Yogyakarta
# Pengembangan Web Profil Cv.Baitusoft Menggunakan Framework Ci
# Pemetaan Pariwisata Di Yogyakarta Menggunakan Google Map Dengan Sistem Android Mobile Sebagai Panduan Wisata
# Pembuatan Model Enterprise Resource Planning (Erp)Pada Xt Square Yogyakarta
# Pembuatan Model Enterprise Architecture Planning (Eap)Unit Sinyal Telekomunikasi Dan Kelistrikan (Sintelis)Pt. Kereta Api Indonesia (Persero) Daop 6 Yogyakartaberbasis Zachman Framework
# Otomatisasi Pemisahan Bandwith Iix (Indoneia Internet Exchange) Dan Ix (Intternet Exchange) Menggunakan Mikrotik Routeros
# Optimasi Frame Rate Pada Game Yang Dikembangkan Dengan Fps Creator
# Optimasi Raw Material Untuk Menekan Biaya Pembuatan Beton Siap Pakai (Ready Mix) (Studi Kasus Di Pt. Patsean Sumber Rejeki)
# Optimasi Penyimpanan Cache Menggunakan Coss (Cyclic Object Storage System) Studi Kasus Pada Smp Muhammadiyah 7 Yogyakarta
# Optimalisasi Penyimpanan Video Menggunakan Viseocache Pada Proxy Server
# Optimalisasi Website Fakultas Teknologi Industri Universitas Ahmad Dahlan Sesuai Algoritma Google Panda Dan Penguin
# Optimalisasi Keamanan Jaringan Lan (Local Area Network)Di Smk N 2 Wonosari
# Optimasi Kinerja Jaringan Menggunakan Metode Scheduler(Studi Kasus Di Laboratorium Jaringan Universitas Ahmad Dahlan)
# Model Sistem Pendukung Keputusan Penilaian Kelayakan Pemberian Kredit
# Model Penentuan Status Gizi Balita Di Puskesmas
# Mobile Application Menggunakan Personal Digital Assistance (Pda) Untuk Mendukung Pelayanan Pengunjung Restoran
# Membangun Sistem Pelacakan Barang Secara Realtime Berbasis Mobile Push Notification
# Membangun Image Editor Online Yang Terhubung Dengan Facebook Api
# Membangun Game Education Saringman Guna Menanamkan Kebersihan Sejak Dini Kepada Anak
# Membangun Aplikasi E Learning Di Fkip Universitas Muhammadiyah Purworejo
# Membangun Aplikasi Autogenerate Script Ke Flowchart Untuk Mendukung Business Process Reengineering
# Membangun Sistem Vrrp (Virtual Router Redundancy Protocol) Menggunakan Sistem Operasi Freebsd (Studi Kasus Di Laboratorium Jaringan Uad)
# Membangun Sistem Terintegrasi Berbasis Web Sdit Luqman Al-Hakim
# Membangun Sistem Pembuatan Resep Obat Untuk Mencegah Pemalsuan Dengan Teknik Code Generator Berbasis Web
# Membangun E-Shop Untuk Kerajinan Kulit Manding Yogyakarta Menggunakan Framework Codeigniter
# Membangun Basis Pengetahuan Untuk Mendiagnosa Penyakit Pada Kelamin Dengan Model Penalaran Berbasis Kasus (Case Based Reasoning)
# Membangun Aplikasi Pembelajaran Penyederhanaan Fungsi Boolean Dengan Metode Quine-Mccluskey
# Membangun Aplikasi Layanan Informasi Pelanggan Pdam Berbasis Sms {Studi Kasus : Pdam Tirtamarta Kota Yogyakarta}
# Media Pembelajaran Tentang Pecahan Sederhana Dan Penggunaannya Dalam Pemecahan Masalah Untuk Sekolah Dasar (Sd) Kelas 3 (Studi Kasus Sdit Lukman Al Hakim Yogyakarta)
# Media Pembelajaran Perhitungan Determinan Reduksi Minor Ekspansi Kofaktor Dan Adjoin
# Media Pembelajaran Materi Perbaikan Kualitas Citra Pada Mata Kuliah Pengolahan Citra
# Media Pembelajaran Materi Context Free Grammar Pada Mata Kuliah Teori Bahasa Otomata
# Media Pembelajaran Bahasa Indonesia Tentang Menentukan Tema Dan Topik Cerita Untuk Sekolah Dasar Kelas 4 (Studi Kaus Sdit Lukman Al Hakim Yogyakarta)
# Media Pembelajaran Algoritma Kriptografi Product Cipher Termodifikasi
# Media Konsultasi Untuk Penyakit Saluran Pernafasan Pada Manusia Menggunakan Metode Case Base Reasoning
# Media Pembelajaran Tentang Menggunakan Pengukuran Waktu, Panjang Dan Berat Dalam Pemecahan Masalah Untuk Sekolah Dasar (Sd) Kelas 3
# Media Pembelajaran Berbasis Komputer Mata Pelajaran Matematika Tentang Bilangan Untuk Sekolah Dasar Kelas Iii (Sudi Kasus Sd It Lukman Al Hakim Yogyakarta)
# Media Pembelajaran Aplikasi Jarimatika Tambah Kurang Untuk Anak Berbasis Mutimedia
# Media Layanan Informasi Pajak Bumi Dan Bangunan Berbasis Jquery Mobile Di Kabupaten Sleman
# Media Konsultasi Penentuan Penyakit Pada Balita Dengan Solusi Herbal Berbasis Kasus
# Manajemen Paket Ubuntu Linux Dengan Repository Server Berbasis Lighttpd 1.4.11
# Managemen Ruang Pasien Rawat Inap Pada Rs Pku Muhammadiyah Yogyakarta Dengan Teknologi Java (Studi Kasus Rumah Sakit Pku Muhammadiyah Jl. Kh. Ahmad Dahlan Yogyakarta)
# Majalah Elektronik Sekolah Berbasis Web Pada Mts Al Mahalli Pleret Bantul
# Media Pendukung Pembelajaran Proses Enkripsi Dan Dekripsi, Algoritma Cryptography Cbc, Vigenere Chiper, Block Transposition Dan Cbc Modifikasi Dalam Pengamanan File Teks Dan Data Teks
# Location Based Service Rental Berdasarkan Info Cd Untuk Mempercepat User Dalam Mencari Judul Cd
# Layanan Penjualan Produk Fitnes Di Victory Fitness Center Berbasis Web Menggunakan Aplikasi Aura Cms
# Layanan Informasi Lokasi Event Menggunakan Location Based Service (Lbs) Berbasis Jquery Mobile
# Jaringan Syaraf Tiruan Backpropagation Untuk Diagnosa Penyakit Hepatitis
# Jaringan Syaraf Tiruan Backpropagation Untuk Diagnosa Hipertensi Dan Stroke
# Informasi Pelayanan Dan Manasik Haji Berbasis Web
# Indie Net Labels Berbasis Web
# Implementasi Staging Dalam Animasi Perilaku Konsumsi Makanan Sehat
# Implementasi Sistem Keamanan Data Menggunakan Algoritma Tea Pada Aplikasi E-Learning
# Implementasi Proxy Server Dan Load Balancing Menggunakan Metode Per Connection Classifier (Pcc) Berbasis Mikrotik
# Implementasi Metode Interpolasi Linier Untuk Mengidentifikasi Kekeruhan Air Dengan Pemrosesan Awal Pelembuyan Citra (Studi Kasus : Pdam Tirtamarta Yogyakarta)
# Implementasi Metode Canny Untuk Deteksi Tepi Mutu Daun Tembakau
# Implementasi Kriptografi Kunci Publik Elgamal Untuk Proses Enkripsi Dan Dekripsi Guna Pengamanan File Data
# Implementasi Keamanan Data Menggunakan Algoritma Blowfish Dan Lsb Pada Citra
# Implementasi Jaringan Syaraf Tiruan Perceptron Untuk Menentukan Tokoh Pewayangan
# Implementasi Expert System Untuk Mendiagnosis Penyakit Mata Menggunakan Dhempster Shafer
# Implementasi Case Base Reasoning Pada Sistem Pakar Dalam Menentukan Jenis Gangguan Kejiwaan
# Implementasi Back Office Aplikasi M-Goverment (Studi Kasus: Pemerintah Kota Yogyakarta)
# Implementasi Web Service Pada Sirkulasi Perpustakaan Menggunakan Data Base Terdistribusi
# Implementasi Web Service Menggunakan Simple Object Access Protocol Studi Kasus Afiliasi Amazon.Com
# Implementasi Wap Pada Pemesanan Tiket Bis
# Implementasi Virtual Reality (Vr) 3D Hotel Merak Indah Klaten
# Implementasi Virtual Private Network (Vpn) Untuk Keamanan Komunikasi Data Pada Jaringan Berbasis Wireless
# Implementasi Transformasi Wavelet Sebagai Pemrosesan Awal Dalam Sistem Pengenalan Wajah Citra Digital
# Implementasi Teknik Untuk Kompresi Citra Digital
# Implementasi Teknik Character Animation Dan Teknik Masking Dalam Pembuatan Film Animasi Kejujuran
# Implementasi Sistem Pakar Untuk Pengobatan Bekam Dengan Metode Case Base Reasioning
# Implementasi Sistem Pakar Untuk Mendiagnosa Penyakit Dalam Pada Manusia Menggunakan Metode Dempster Shafer
# Implementasi Sistem Management User Pada Hotspot Menggunakan Freeradius Dan Coova-Chilli (Studi Kasus Biskom Universitas Ahmad Dahlan)
# Implementasi Network Monitoring Untuk Meningkatkan Kinerja Jaringan Studi Kasus Laboratorium Jaringan Uad
# Implementasi Metode Limited Cut Dan Post Planning Animation Dalam Pembuatan Film Animasi Kebersihan Adalah Sebagian Dari Iman
# Implementasi Manajemen Bandwidth Menggunakan Hierarchical Token Bucket (Htb) Pada Sistem Operasi Linux (Studi Kasus Di Laboratorium Jaringan Uad)
# Implementasi Manajemen Bandwidth Dan Web Proxy Menggunakan Clearos Di Smk N 1 Pengasih
# Implementasi Keamanan Data Menggunakan Algoritma Gost Dan Steganografi Pada Citra
# Implementasi Image Watermarking Pada Citra Digital Menggunakan Teknik Discrete Fourier Transform (Dft) Dan Singular Value Decomposition (Svd)
# Implementasi Image Watermarking Pada Citra Digital Dengan Discrete Wavelet Transform (Dwt) Daubechies D4
# Implementasi Honeypot Untuk Meningkatkan Keamanan Jaringan Berbasis Wireless
# Implementasi Grafika Komputer Follow-Thruough And Overlapping Actions Pada Pembuatan Film Kartun Nilai Nilai Keikhlasan
# Implementasi E-Commerce Untuk Penjualan Buku Pada Penerbit Ombak Berbasis Framework
# Implementasi Case Based Reasoning Untuk Mendiagnosa Penyakit Paru Pada Manusia
# Implementasi Case Based Reasoning Pada Sistem Pakar Diagnosa Penyakit Kanker Berbasis Web
# Implementasi Algoritma Kriptografi Simetri Aes Dan Asimetri Elgamal Pada Dokumen Microsoft Office
# Identifikasi Iris Mata Manusia Dengan Jaringan Saraf Tiruan
# Implementasi Majalah Dinding Pada Platform Android
# Hubungan Antara Tingkat Pengetahuan Bahaya Merokok Dengan Perilaku Merokok Pd Mahasiswa Teknik Informatika Uad Yogyakarta
# Game Edukasi Meningkatkan Daya Ingat Anak Bermain Bersama Modo Dan Modi
# Game Edukasipengenalan Rambu-Rambu Lalu Lintas Untuk Anak Usia Dini (Studi Kasus Tk Asyiah Bustanul Athfal Janturan)
# Game Adventure Menggunakan Metode Side Scrolling Cerita Rakyat Doyan Nada Untuk Meningkatkan Pemahaman Budayasasak (Lombok) Pada Anak
# Front System Menggunakan M-Government Untuk Meningkatkan Interaksi Masyarakat Dan Pemerintah Yogyakarta
# Enterprise Arsitectur Planning Produksi Gula Dengan Zachman Framework
# Embedded Graphic Online Service
# E-Readiness Pembuatan Model Sistem M-Government (Studi Kasus: Pemerintah Kota Yogyakarta)
# Diagnosa Kerusakan Printer Dengan Pendekatan Sistem Pakar Menggunakan Metode Theorema Bayes Berbasis Web
# Deteksi Penyakit Tulang Menggunakan Jaringan Syaraf Tiruan Dengan Metode Backpropagation
# Deteksi Penyakit Dan Serangan Hama Tanaman Buah Salak Menggunakan Jaringan Syaraf Tiruan (Jst) Dengan Metode Perceptron
# Deteksi Penyakit Ayam Menggunakan Jaringan Syaraf Tiruan Dengan Metode Perceptron
# Deteksi Penyakit Saluran Pernafasan Dengan Jaringan Syaraf Tiruan Metode Perceptron
# Deteksi Penyakit Autis Dengan Jaringan Syaraf Tiruan Algoritma Perceptron
# Deteksi Kecacatan Pada Gerabah Menggunakan Metode Canny
# Deteksi Jenis Ikan Hias Menggunakan Metode Canny
# Deteksi Dini Perilaku Penyimpangan Seksual Menggunakan Metode Fordward Chaining Berbasis Web
# Desain Dan Implitasi Sms Gateway Untuk Layanan Hasil Studi Mahasiswa (Studi Kasus Pada Prodi Teknik Informatika Informatika Uad)
# Desain Dan Implementasi Jejaring Sosial Bagi Penggemar Sepak Bola Berbasis Web
# Desain Dan Implementasi Virtualisasi Server Menggunakan Proxmox
# Desain Dan Impelementasi E-Counseling Pada Program Studi Bimbingan Konseling (Studi Kasus Di Program Bimbingan Konseling Uad Yogyakarta)
# Desain Dan Implementasi Web E-Commerce Pada Pemesanan Buku Secara Online (Studi Kasus Di Divaprees Publisher)
# Decision Support System Penilaian Kinerja Guru Berdasarkan Standar Kurikulum Tingkat Satuan Pendidikan (Ktsp)
# Computer Based Training Teknik Rancang Bangun Menggunakan Aplikasi Autocad
# Bank Lokasi Fasilitas Umum Di Kota Yogyakarta Berbasis Web Service
# Arsitektur Teknologi Informasi Dan Komunikasi Menggunakan Framework Zachman (Studi Kasus: Biro Finansial Dan Aset (Bifas) Universitas Xyz)
# Aplikasikartu Nama Virtual (Virtual Business Card) Berbasis Web Mobile
# Aplikasi Terjemahan Bahasa Indonesia Ke Bahasa Batak Angkola Atau Sebaliknya Berbasis Android
# Aplikasi Terjemah Bahasa Indonesia-Seraway, Seraway-Indonesia
# Aplikasi Sistem Pendukung Keputusan Bagi Penentuan Tingkat Epidemi Di Puskesmas Induk Umbulharjo I Kota Yogyakarta
# Aplikasi Sistem Pakar Untuk Diagnosa Medis Pada Penyakit Sistem Peredaran Darah Menggunakan Metode Case Based Reasoning
# Aplikasi Sistem Pakar Berbasis Web Untuk Diagnosa Penyakit Pada Tanaman Kelapa Menggunakan Metode Certainty Factor Yang Disertai Gejala Citra
# Aplikasi Sistem Pakar Berbasis Web Untuk Diagnosa Penyakit Pada Tanaman Kelapa Menggunakan Metode Certainly Factor Yang Disertai Gejala Citra
# Aplikasi Penterjemah Untuk Bahasa Indonesia Ke Bahasa Jawa Sebaliknya
# Aplikasi Penterjemah Bahasa Ogan - Indonesia Dan Sebaliknya
# Aplikasi Penterjemah Bahasa Indonesia Ke Bahasa Lampung Disertasi Analisis Sintaksis
# Aplikasi Penterjemah Bahasa Indonesia Ke Bahasa Komering Dan Sebaliknya
# Aplikasi Pengolahan Citra Untuk Mendeteksi Kualitas Daging Sapi Berdasarkan Fitur Tekstur Berbasis Histogram Citra
# Aplikasi Pengolahan Citra Untuk Deteksi Tingkat Kematangan Semangka Berdasarkan Fitur Tekstur Kulit Buah
# Aplikasi Pengolahan Citra Menggunakan Metode Thresholding Untuk Mendeteksi Kerusakan Gerabah
# Aplikasi Pengetahuan Dasar Hiv Dan Aids Berbasis Android
# Aplikasi Penerjemah Bahasa Indonesia Ke Bahasa Banjar Dan Sebaliknya Dengan Analisis Sintaksis
# Aplikasi Pemrosesan Bahasa Alami Bahasa Indonesia Ke Bahasa Perintah Dos
# Aplikasi Metode Region Growing Untuk Monitoring Pertumbuhan Panjang Kecambah
# Aplikasi Game Side Scrolling Jaka Tarub Dan 7 Bidadari
# Aplikasi Game Arcade Bajak Laut Berbasis Java J2Me
# Aplikasi Deteksi Kerusakan / Cacat Pada Sambungan Las Menggunakan Metode Region Growing
# Aplikasi Bantu Pengolahan Nilai Indeks Kinerja Dosen (Studi Kasus Fakultas Teknologi Industri Uad)
# Aplikasi Android Untuk Media Promosi Dan Publikasi Penjualan Mobil Di Kota Pekalongan Dengan Metode Android Notification
# Aplikasi Wap Untuk Pengembangan Website Di Pmi Cabang Kota Yogyakarta
# Aplikasi Web E-Learning Sebagai Media Pembelajaran Alternatif Di Sma (Studi Kasus Aplikasi Web E-Learning Sma Negeri 1 Rembang Kabupaten Purbalingga)
# Aplikasi Visualisasi Pemodelan Data Pada Struktur Basis Data
# Aplikasi Uji Coba Toefl Berbasis Web Pada Smu Muhammadiyah Ii Yogyakarta
# Aplikasi Try Out Bahasa Inggris Untuk Ujian Nasional Sekolah Menengah Atas
# Aplikasi Transliterator Dan Translator Bahasa Indonesia Ke Bahasa Korea Dan Bahasa Korea Ke Bahasa Indonesia
# Aplikasi Transformasi Watershed Untuk Segmentasi Citra Dengan Spatial Filter Sebagai Pemroses Awal
# Aplikasi Transformasi Warna Ycbcr Untuk Deteksi Jenis Warna Kulit Tomat Dalam Fase Kematangan Tomat
# Aplikasi Toko Buku Online Berbasis Sms Gateway Over Gprs (General Packet Radio Service)
# Aplikasi Tes Kepribadian Untuk Penempatan Karyawan Menggunakan Metode Myers-Briggs Type Indicator (Mbti) Berbasis Web (Studi Kasus: Pt. Winata Putra Mandiri)
# Aplikasi Tes Kepribadian Menggunakan Metode Edwars Personal Prefefence Schedul (Studi Kasus Cv Exist Klaten Jawa Tengah
# Aplikasi Tes Intelligence Quotient (Iq) Menggunakan Standarisasi Wechsler Berbasis Web
# Aplikasi Terjemahan Untuk Belajar Bahasa Jawa Dan Aksara Jawa
# Aplikasi Terjemahan Bahasa Indonesia-Sunda Dan Sebaliknya Berbasis Wap (Wireless Application Protocol)
# Aplikasi Terjemahan Bahasa Indonesia Ke-Bahasa Ternate Disertai Dengan Pemeriksaan Kalimat Ambigu
# Aplikasi Terjemahan Bahasa Indonesia Ke Bahasa Tolaki Dan Sebaliknya
# Aplikasi Terjemahan Bahasa Indonesia Ke Bahasa Tidore Disertai Dengan Analisis Sintak
# Aplikasi Terjemahan Bahasa Indonesia Ke Bahasa Jawa Dilengkapi Dengan Pengecekan Kalimat Ambigu
# Aplikasi Terjemahan Bahasa Indonesia Ke Bahasa Banyumas Dengan Analisis Teknik
# Aplikasi Sumbangan Pembinaan Pendidikan Berbasis Web Yang Terintegrasi Dengan Sms Gateway Dan Email Server
# Aplikasi Sistem Tes Online Smp 1 Ponjong Gunungkidul
# Aplikasi Sistem Penilaian Kinerja Karyawan Untuk Kenaikan Jabatan Dengan Metode Behaviourally Anchored Rating Scale (Bars) Berbasis Web
# Aplikasi Sistem Pendukung Keputusan Penentuan Lokasi Pendirian Warnet Dengan Metode Analytical Hierarchy Process (Ahp) (Studi Kasus Pt Pika Media Komunika)
# Aplikasi Sistem Pendukung Keputusan Dalam Penentuan Lokasi Pembangunan Ruko Dengan Metode Naive Bayes
# Aplikasi Sistem Pakar Untuk Mendiagnosa Penyakit Hati Dengan Penyajian Jaringan Semantik
# Aplikasi Sistem Pakar Untuk Mendiagnosa Penyakit Infeksi Pada Usus Manusia
# Aplikasi Sistem Pakar Untuk Mendiagnosa Gangguan Perkembangan Kesehatan Anak Dengan Metode Certainty Factor (Cf)
# Aplikasi Sistem Pakar Untuk Diagnosa Penyakit Pada Tanaman Hias Berbasis Web Dengan Menggunakan Teorema Bayes
# Aplikasi Sistem Pakar Penentuan Perawatan Kecantikan Berbasis Web (Studi Kasus: Pamella Salon Yogyakarta)
# Aplikasi Sistem Pakar Diagnosa Infeksi Sistem Gastro-Usus Dengan Penyajian Jaringan Semantik
# Aplikasi Sistem Pakar Diagnosa Hama Dan Penyakit Tembakau Menggunakan Teorema Bayes
# Aplikasi Short Message Service (Sms) Gateway Sebagai Layanan Informasi Harga Dan Pemesanan Makanan Berbasis Sms
# Aplikasi Sms Gateway Untuk Reservasi Pada Hotel Imperial Aryaduta Lippo Karwaci
# Aplikasi Sms Gateway Sebagai Layanan Informasi Santri Bagi Wali Santri Pada Pondok Pesantren Ibnul Qoyyim
# Aplikasi Sms Gateway Sebagai Layanan Informasi Jalur Bis Di Yogyakarta Serta Perkiraan Waktu Tempuh Berdasarkan Kecepatan Rata-Rata Bis Berbasis Sms
# Aplikasi Sms Dengan Microsoft Visual Basic Dan Mobile Fbus 1.5 Activex Control
# Aplikasi Sig Untuk Mencegah Interferensi Antar Stasiun Pemancar Radio Di Wilayah Daerah Istimewa Yogyakarta
# Aplikasi Puzzle Game Sebagai Program Bantu Pembelajaran
# Aplikasi Program Pembelajaran Sains Sekolah Dasar
# Aplikasi Perbandingan Pencarian Jalur Terpendek Antara Jaringan Syaraf Tiruan Kohonen Self Organizing Maps Dengan Jaringan Syaraf Tiruan Boltzmann Machine
# Aplikasi Perbaikan Citra Digital Untuk Mengidentifikasi Kerusakan/Cacat Pada Film Radiografi Sambungan Las
# Aplikasi Perangkat Lunak Perawatan Kendaraan Di Po.Maju Lancar Yogyakarta Dengan Pemrograman Delphi 6.0
# Aplikasi Perangkat Lunak Penggajian Karyawan Di Mirota Gejayan
# Aplikasi Penterjemah Untuk Bahasa Indonesia Ke Bahasa Cirebon Dan Sebaliknya
# Aplikasi Penterjemah Bahasa Indonesia-Bahasa Sunda Dan Sebaliknya Berbasis Sms
# ...
# Analisis Penilaian Risiko Pada Sistem Informasi Manajemen Penilaian Menggunakan Kerangka Kerja Octave Allegro Studi Kasus : Sma Muhammadiyah 1 Yogyakarta
# Analisis Penilaian Risiko Pada Layanan Repositori Eprints Menggunakan Framework Octave Allegrostudi Kasus Perpustakaan Universitas Ahmad Dahlan
# Analisis Penilaian Risiko Menggunakan Framework Octave Allegro Studi Kasus Sistem Informasi Manajemen Perpustakaan Sma Muhammadiyah 1 Yogyakarta
# Analisis Penerapan Sistem Informasi Manajemen Dalam Peencanaan Obat Di Rs Pku Muhammadiyah Yogyakarta Unit Ii
# Analisis Penerapan Sistem Informasi Di Bagian Pembayaran Pasien Rawat Jalan Rsud Kabupaten Namlea Provinsi Maluku
# Analisis Manajemen Risiko Keamanan Informasi Dengan Menggunakan Metode Octave-S Studi Kasus Sistem Informasi Manajemen Rumah Sakit Pku Muhammadiyah Yogyakarta
# Analisis Kepuasan Pengguna Pada Website Smk Muhammadiyah 1 Bambanglipuro Menggunakan Metode Technology Acceptance Model (Tam)
# Analisis Kepuasan Pengguna Website Menggunakan Metode Technology Acceptance Model (Tam)Studi Kasus Website Profile Universitas Ahmad Dahlan
# Analisis Kepuasan Pengguna Simpus Menggunakan Technology Acceptance Model (Tam)
# Analisis Kepuasan Pengguna Pada Portal Akademik Menggunakan Metode Technology Acceptance Model (Tam)
# Analisis Kebutuhan Si/Ti Untuk Mini Bank Syariah Dengan Menggunakan Zachman Framework
# Analisis Faktor-Faktor Yang Mempengaruhi Minat Pemanfaatan Dan Penggunaan Sistem Informasi ( Studi Pada Pemerintah Daerah Bantul)
# Analisis Faktor-Faktor Yang Mempengaruhi Penerimaan Sistem Informasi Manajemen Puskesmas (Simpus) Dengan Tam Di Puskesmas Sebengkok Kota Tarakan Kalimantan Utara
# Analisis Dan Perancangan Proses Bisnis Dan Basis Data Untuk Sim (Sistem Informasiâ  Managemen) Lsp Ad
# Analisis Dan Pemodelan Sistem Informasi Stok Gudang Di Koperasi Dishutbun Cianjur Menggunakan Supply Chain Management
# Analisis Dan Konfigurasi Website Electronic Commerce Trafik Tinggi Dengan Teknik Search Engine Optimization (Seo) (Studi Kasus Website Rukun Makmur Knalpot Purbalingga)
# Aplikasi Sistem Informasi Pariwisata Daerah Bima Berbasis Android
# Analisis Sistem Informasi Pendaftaran Pasien Dengan Menggunakan Free Open Source Software (Foss) Dipuskesmas Umbulharjo Ii Yogyakarta
# Analisis Sistem Informasi Manajemen Sumber Dayamanusia Di Rumah Sakit Pku Muhammadiyah Yogyakartatahun 2015
# Analisis Penerapan Sistem Informasi Manajemen Dalamperencanaan Obat Di Rs Pku Muhammadiyahyogyakarta Unit Ii
# An Analysis Of Users Acceptance Of Classroom Management Information System At Abc University By Using Technology Acceptance Model As A Basis For System Maintenance
# Usulan Perbaikan Untuk Pencapaian Sistem Manajemen Mutu Iso 9001:2008 Dengan Metode Analytic Hierarchy Process Studi Kasus Di Smti Yogyakarta
# Up Grade Sistem Manajemen Mutu Iso 9001:2008 Di Pt. Mega Andalan Kalasan Yogyakarta
# Sistem Manajemen Penjualan Berbasis Multi User Pada Perusuhaan Kontraktor Cv. Restoe Boemi Karanganyar Surakarta
# Sistem Manajemen Penyewaan Kamar Losmen Berbasis Website
# Sistem Manajemen Pemberitaan Surat Kabar Oku Ekspres Di Baturaja Berbasis Web
# Sistem Manajemen Faktur Farmasi
# Perancangan Upaya Peningkatan Kualitas Pelayanan Rawat Inap Dengan Metode Benchmarking (Studi Kasus Pada Rs Pku Muhammadiyah Bantul Dan Rs Pku Muhammadiyah Yogyakarta)
# Pengembangan Sistem Informasi Manajemen Penyelenggaraan Pertandingan Pencak Silat Tapak Suci
# Pengembangan User Experience (Ux) Dan User Interface (Ui) Aplikasi Sistem Manajemen Perpustakaan Desa Berbasis Mobile
# Pengembangan User Experience (Ux) Dan User Interface (Ui) Sistem Manajemen Sengketa Informasi Komisi Informasi Provinsi Diy
# Pengembangan Sistem Manajemen Presensi Rapat Menggunakan Qr Code Pada Android
# Penerapan Sistem Manajemen Mutu Iso 9001:2008 Dalam Meningkatkan Kinerja Guru Di Smk Muhammadiyah 3 Yogyakarta
# Penerapan Secret Sharing Menggunakan Algoritma Shamir Pada Sistem Manajemen Akun Berbasis Framework Codeigniter
# Pengembangan User Experience (Ux) Dan User Interface (Ui) Sistem Manajemen Perpustakaan Desa Berbasis Saas
# Konsep Plan, Do, Check, Action (Ppca)Â  Pada Sistem Manajemen Keselamatan Dan Kesehatan Kerja (Smk3) Pltu Expantion 1X660 Mw Cilacap
# Implementasi Sistem Manajemen Keselamatan Dan Kesehatan Kerja (Smk 3) Di Rs Grhasia Propinsi Diy
# Evaluasi Penerapan Sistem Manajemen Keselamatan Dan Kesehatan Kerja (Smk3) Pada Bagian Bongkar Muat Semen Di Gudang Pt. Holcim Indonesia Tbk Yogyakarta
# Evaluasi Pelaksanaan Sistem Manajemen Keselamatan Dan Kesehatan Kerja [Smk3] Di Rumah Sakit Pku Muhammadiyah Yogyakarta
# Evaluasi Implementasi Sistem Manajemen Keselamatan Dan Kesehatan Kerja Berbasis Ohsas 18001:2007 Dan Iso 14001:2004 Di Pt Len Industri (Persero)
# Evaluasi Sistem Manajemen Keluhan Pelanggan Di Rumah Sakit Pku Muhammadiyah Bantul Yogyakarta
# Evaluasi Pelaksanaan Sistem Manajemen Logistik Penanggulangan Klb Malaria Di Puskesmas Paruga Rasanae Barat Kota Bima Propinsi Ntb Tahun 2009.
# Desain Dan Implementasi Sistem Manajemen Reservasi Hotel
# Desain Dan Implementasi Sistem Manajemen Penjualan Seluler Online
# Desain Dan Implementasi Sistem Manajemen Apartement Mahasiswa
# Analisis Sistem Manajemen Pengelolaan Rekam Medis Di Rumah Sakit Islam Manisrenggo Klaten
# Analisis Sistem Manajemen Pelayanan Voluntary Counseling And Testing (Vct) Hiv/Aids Di Rsj Grhasia Yogyakarta
# Analisis Sistem Manajemen Keselamatan Dan Kesehatan Kerja Di Pt. Pabrik Gula (Pg) Unit Tolangohula Kabupaten Gorontalo
# Analisis Sistem Manajemen Keselamatan Dan Kesehatan Kerja ( Smk3) Di Perkebunan Kelapa Sawit Pt. Sawindo Kencana Kabupaten Bangka Barat
# Analisis Sistem Manajemen Keselamatan Dan Kesehatan Kerja Dengan Menggunakan Metode Siklus Pdca (Studi Kasus Pada Industri Kerajinan Perak Salim Silver Kotagede Yogyakarta)
# Analisis Penerapan Sistem Manajemenâ  Keselamatan Dan Kesehatan Kerja Di Gardu Induk 150 Kvâ  Bantulâ  Pt. Plnâ  ( Persero) Tjbt App Salatiga
# Analisis Penerapan Sistem Manajemen Keselamatan Dan Kesehatan Kerja Di Pt. Kaltim Jaya Bara Kalimantan Timur
# Analisis Penerapan Sistem Manajemen Keselamatan Dan Kesehatan Kerja (Smk3) Di Pt. Amman Mineral Nusa Tenggara (Amnt) Kabupaten Sumbawa
# Analisis Penerapan Kebijakan Sistem Manajemen Kesehatan Dan Keselamatan Kerja (Smk3) Pada Proses Pemanenan Kelapa Sawit Di Pt Agro Indomas Kabupaten Seruyan
# Analisis Iso 9001:2000 Menuju Perubahan Ke Iso 9001:2008 Sebagai Sistem Manajemen Mutu Smk N 5 Yogyakarta
# Analisis Pelaksanaan Manajemen Risiko Keselamatan Dan Kesehatan Kerja (K3) Di Bagian Produksi Pt Holcim Kabupaten Cilacap
# Prototype Kamus Indonesia-Arab Menggunakan Unicode Arabic
# Penggunaan Metode Binary Search Pada Aplikasi Penterjemah Bahasa Indonesia Ke Bahasa Berau
# Pengembangan Kamus Kata Bahasa Jawa Ngoko - Krama Alus Dengan Menggunakan Metode Sequential Search
# Pengembangan Kamus Istilah Kesenian Seni Rupa Dengan Fitur Spellcheck Levenshtein Distance
# Pengembangan Kamus Istilah Dengan Makna Bahasa Indonesia - Jawa Menggunakan Squential Search
# Pengembangan Kamus Fisika Berbasis Android Untuk Sma/Ma Kelas X
# Pengembangan Chatbot Kamus Bahasa Indonesia Dan Integrasi Dengan Google Assistant Bahasa Indonesia
# Pengembangan Aplikasi Kamus Istilah Motor Vespa Berbasis Web
# Penerapan Metode Left Corner Parsing Dalam Aplikasi Terjemahan Bahasa Indonesia Ke Bahasa Bima
# Penerapan Algoritma Boyer-Moore Dalam Aplikasi Kamus Istilah Broadcasting
# Pembuatan Kamus Elektronis Sistem Isyarat Bahasa Indonesia Bagi Tuna Rungu
# Pemanfaatan N-Gram Pada Pengembangan Kamus Bahasa Indonesia - Bima
# Pengaruh Bunyi Plosif Terhadap Makna Bahasa Arab Di Dalam Kamus Al-Munawwir Arab - Indonesia
# Media Pembelajaran Bahasa Sasak Dilengkapi Dengan Kamus Bahasa Sasak-Bahasa Indonesia Berbasis Multimedia
# Kamus Basket Online Berbasis Web Pada Klub Basket Mahaputra
# Implementasi Natural Language Processing Pada Kamus Online Bahasa Indonesia-Bahasa Melayu Riau
# Implementasi Analisis Semantik Dalam Kamus Terjemahan Indonesia-Bima Berbasis Teknologi Mobile
# E-Dictionary Berbasis J2Me Menggunakan Telepon Seluler
# Aplikasi Terjemahan Bahasa Indonesia - Sunda Dengan Undak Usuk Basa Sunda (Uubs) Menggunakan Metode Sequentrial Search
# Aplikasi Kamus Slang Menggunakan Algoritma Brute Force
# Aplikasi Kamus Istilah Pembelajaran Permainan Bola Basket Menggunakan Delphi Dalam Paket Multimedia
# Aplikasi Kamus Digital Menggunakan Macromedia Flash 8 {Flash Lite}
# Aplikasi Kamus Bahasa Sumbawa Ke Indonesia Dan Sebaliknya Dengan Metode Sequential Search Berbasis Web
# A Descriptive Analysis Of English Borrowing In Kamus Besar Bahasa Indonesia Pusat Bahasa By Departemen Pendidikan Bahasa
# Text Mining Klasifikasi Judul Skripsi Teknik Industri Universitas Ahmad Dahlan Berdasarkan Bidang Minat Menggunakan Metode Naive Bayes
# Pemanfaatan Text Mining Untuk Mengklasifikasi Sms Spam Porno Dengan Algoritma C4.5
# Sistem Pengenalan Wajah Manusia Secara Realtime Menggunakan Algoritma Jaringan Saraf Tiruan
# Perencanaan Dan Pengendalian Tingkat Kekerasan Permukaan Benda Kerja Hasil Pembuatan Menggunakan Backpropagation Artificial Neural Network
# Pengenalan Wajah Untuk Presensi Mahasiswa Menggunakan Metode Convolutional Neural Networks
# Analisis Prediksi Jumlah Tamu Hotel Tirta Arum Wonosobo Menggunakan Metode General Reggression Neural Network (Grnn)
# Usulan Peningkatan Kualitas Pelayanan Dengan Pendekatan Fuzzy Dan Metode Service Quality (Studi Kasus Perusahaan Penyedia Jasa Internet Jagonet)
# Sistem Penentuan Nutrisi Balita Dengan Metode Fuzzy C-Means Berdasarkan Produk Kemasan Berbasis Mobile
# Sistem Penentuan Nutrisi Balita Dengan Metode Fuzzy C-Means Berdasarkan Produk Kemasan
# Sistem Pendukung Keputusan Dengan Fwp Untuk Menentukan Alternatif Tujuan Wisata Terbaik (Studi Kasus: Objek Wisata Di Diy)
# Sistem Pendukung Keputusan Status Gizi Balita Untuk Membantu Kinerja Puskesmas Dengan Metodeâ  Fuzzy Tsukamoto
# Sistem Pendukung Keputusan Menggunakan Basis Data Fuzzy Model Tahani Untuk Membantu Pemilihan Telepon Selluler (Studi Kasus Nokia Indonesia)
# Sistem Pendukung Keputusan Mendiagnosa Penyakit Diabetes Melitus Melalui Pendekatan Fuzzy Inference System (Fis) Dengan Metode Tsukamoto
# Sistem Pakar Untuk Mengidentifikasi Penyakit Common Cold Disertai Dengan Pengetahuan Komposisi Obat Menggunakan Logika Fuzzy
# Sistem Pakar Untuk Mendiagnosa Penyakit Vertigo Dan Solusi Penanganannya Menggunakan Logika Fuzzy
# Sistem Pakar Untuk Mendiagnosa Gangguan Kesehatan Pada Anak Beserta Solusinya Yang Didasarkan Pada Perhitungan Logika Fuzzy
# Sistem Pakar Rekomendasi Obat Non- Resep Dokter Dengan Metode Fuzzy Inference System Tsukamoto Berbasis Mobile Android
# Sistem Pakar Diagnosa Masalah Kehamilan Menggunakan Algoritma Fuzzy Tsukamoto
# Sistem Pakar Dengan Inferensi Fuzzy Untuk Menentukan Kualitas Induk Ayam
# Sistem Kendali Kecepatan Motor Dc Menggunakan Algoritma Fuzzy Berbasis Mikrokontroler At89C51
# Sistem Distribusi Irigasi Pertanian Menggunakan Kendali Fuzzy Dan Monitoring Air Berbasis Android
# Sistem Cerdas Untuk Rekomendasi Pemilihan Produk Handphone Menggunakan Basisdata Fuzzy Model Tahanistudi Kasus Produk Handphone Di Jogja Phonsel
# Sistem Pendukung Keputusan Pemilihan Lembaga Bimbingan Belajar Berbasis Fuzzy Tahani
# Sistem Kendali Suhu Menggunakan Logika Fuzzy Berbasisplc Schneider
# Rancang Bangun Sistem Pakar Racikan Tanaman Obat Tradisional Menggunakan Metode Fuzzy Interference System Tsukamotto Berbasis Web
# Prediksi Harga Saham Berbasis Web Menggunakan Logika Fuzzy
# Prediksi Laju Pertumbuhan Penduduk Di Kabupaten Sleman Dengan Metode Adaptive Neuro - Fuzzy Inference System (Anfis) Dan Metode Sugeno
# Perbandingan Hasil Rekomendasi Metode Ahp Dan Metode Fuzzy Madm Dalam Pengambilan Keputusan Dengan Pola Benchmark
# Peramalan Dengan Menggunakan Fuzzy Time Series Chen (Studi Kasus: Peramalan Rata-Rata Curah Hujan Di Diy)
# Peramalan Curah Hujan Menggunakan Metode Adaptive Neuro Fuzzy Inference System (Anfis) (Studi Kasus: Kabupaten Sleman)
# Pengklasteran Dengan Metode Fuzzy C-Means Menggunakan Jarak Euclidean Dan Euclidean Kuadrat
# Penggunaan Kombinasi Jarak Minkowski Dan Chebyshev Pada Fuzzy C-Means Untuk Pengklasteran Data Kategori
# Penggunaan Jarak Kullback Leibler Divergence Pada Fuzzy K-Means Untuk Pengklasteran Data Kategori
# Pengembangan Sistem Pakar Dengan Metode Logika Fuzzy Untuk Membantu Mendiagnosa Gangguan Gizi Pada Anak
# Pengatur Intensitas Cahaya Ruangan Dengan Metode Fuzzy Logic Menggunakan Plc
# Penerapan Data Mining Dalam Melakukan Analisis Pola Asosiasi Pada Data Alumni Menggunakan Metode Fuzzy Assosiasi Di Universitas Ahmad Dahlan
# Penentuan Nominal Beasiswa Yang Diterima Mahasiswa Dengan Metode Fuzzy Tsukamoto Di Universitas Ahmad Dahlan
# Pemilihan Calon Penerimaan Beasiswa Menggunakan Fuzzy Analytical Hierarchy Processâ (Fahp) (Studi Kasus: Beasiswa Ppa Di Uad)
# Pembuatan Sistem Cerdas Pengenalan Tulisan Tangan Aksara Jawa Menggunakan Metode Neuro-Fuzzy
# Pengelompokkan Data Penyakit Berdasarkan Usia Menggunakan Metode Fuzzy C-Means
# Pembuatan Model Customer Relationship Manajement(Crm) E-Goverment Dengan Metode Logika Fuzzydi Dinas Perizinan Kota Yogyakarta
# Optimalisasi Bentuk Kuadratik Dengan Parameter Bilangan Fuzzy
# Metode Fuzzy Untuk Menetukan Alternatif Terbaik Yang Didasarkan Pada Multi Kriteria Dengan Variabel Linguistik
# Media Pembelajaran Himpunan Fuzzy Berbasis Multimedia
# Media Pembelajaran Fuzzy Logic Untuk Metode Tzukamoo Berbasis Multimedia
# Media Pembelajaran Database Fuzzy Dengan Metode Tahani Berbasis Multimedia
# Logika Fuzy Pada Pengaturan Navigasi Robot Line Follower
# Implementasi Fuzzi Inference System Untuk Terapi Bagi Penderita Diabetes Melitus Dengan Metode Sugeno
# Implementasi Pengolahan Citra Terhadap Kualitas Daging Ayam Petelur Menggunakan Fuzzy C-Means
# Implementasi Fuzzy Linear Programming (Flp) Dalam Optimasi Produksi (Studi Kasus: Produksi Bakpia Pathok 'Mas Agus 007')
# Implementasi Data Mining Menggunakan Al-Goritma Fuzzy C-Covering Pada Data Transaksi Penjualan Di Toko Safira
# Implementasi Algoritma Fuzzy C‐Means Untuk Segmentasi Peminjaman Pada Perpustakaan Uad
# Fuzzy Associative Memory Untuk Sistem Pendukung Keputusan Jumlah Produksi
# Fuzzy Multi-Attribute Decision Making (Fmadm) Untuk Perankingan Tingkat Kesejahteraan Masyarakat Indonesia
# Fuzzy C-Means Menggunakan Jarak Manhattan Studi Kasus: Resiko Ibu Hamil Terhadap Pre-Eklampsia
# Aplikasi Metode Mamdani Dan Metode Sugeno Pada Penentuan Ststus Gizi Balita (Studi Kasus: Balita Di Puskesmas Lendah)
# Aplikasi Fuzzy Multi- Attribute Decision Making (Fmadm) Pada Sistem Pendukung Keputusan (Spk) Untuk Mendiagnosis Suatu Jenis Penyakit
# Analisis Prediksi Jumlah Produksi Kakao Di Wilayah Kecamatan Kalibawang Berdasarkan Data Cuaca Menggunakan Metode Adaptive Neuro Fuzzy Interface System (Anfis)
# Analisis Perbandingan Metode Self Organizing Map Dan Metode Fuzzy C-Means Pada Pengelompokkan Peminatan Jurusan Di Sekolah Menengah Kejuruan
# Analisis Investasi Pada Rumah Kontrakan Dengan Menggunakan Metode Fuzzy
# Analisis Fungsi Keanggotaan Metode Fuzzy Tsukamoto Dalam Penentuan Kelas Kesesuaian Lahan Sawah Irigasi
# Alat Pendeteksi Kualitas Daging Sapi Berdasarkan Warna, Bau Dan Kelembaban Berbasis Stmf103C8T6 Menggunakan Logika Fuzzy
# Alat Bantu Ajar Mata Kuliah Fuzzy Logic Pada Pokok Bahasan Metode Sugeno Berbasis Multimedia
# Adaptive Neuro Fuzzy Inference System Untuk Peramalan Jumlah Wisatawan (Studi Kasus: Peramalan Jumlah Wisatawan Mancanegara Di Diy)
# Aplikasi Pengolahan Citra Untuk Identifikasi Kematangan Mentimun Berdasarkan Tekstur Kulit Buah Dengan Metode Logika Fuzzy C-Means
# Penerapan Text Mining Pada Sistem Klasifikasi Email Spam Menggunakan Metode Naive Bayes
# Penerapan Text Mining Untuk Pengelompokan Trend Judul Skripsi Pada Program Studi Teknik Industri Universitas Ahmad Dahlan Menggunakan Metode K-Means Dengan Cosine Similarity
# Penerapan Text Mining Pengelompokkan Judul Kerja Praktek Menggunakan Metode K-Means Clustering Dengan Cosineâ  Similarity
# Penerapan Text Mining Pengelompokan Judul Manajemen Tugas Proyek Menggunakan Metode K-Means Dengan Cosine Similarity

# %%
pre
# Out:
# ['ancang model supply chain management scm analisis balanced scorecard bsc pa dhanar',
#  'website update skor tanding sepak bola liga indonesia',
#  'web service backend manajemen pustaka desa bas konsep software as a service saas',
#  'visualisasi teknik obat akupuntur animasi d',
#  'visualisasi proses enkripsi deskripsi metode adfgvx product cipher cipher block chaining',
#  'visualisasi tanggulang bahaya demam darah',
#  'visualisasi materi kuliah kimia ancang menara distilasi multikomponen',
#  'visualisasi erupsi gunung rap non explosive bas  d',
#  'visualisasi struktur bangun rumah tahan gempa bas d',
#  'visualisasi ajar algoritma dijkstra untuk cari lintas pendek',
#  'visualisasi bangkit listrik tenaga surya solar sel',
#  'visualisasi leta buku pustaka guna java studi kasus pustaka daerah yogyakarta',
#  'visualisasi maxinari residence tentu harga rumah dasar satu bahan maxinari residence media pasar',
#  'visualisasi algoritma cipher block chaining media ajar bas mobile android',
#  'verifikasi wajah untuk sistem presensi mahasiswa',
#  'translator bahasa mandarin indonesia bas wap',
#  'theme generator cms wordpress guna teknologi html  untuk mudah buat theme media promosi studi kasus synchronous yogyakarta',
#  'test interest of multiple intelligences bas web studi kasus sd juara yogyakarta',
#  'teknologi augmented reality untuk kembang aplikasi kenal motif songket palembang',
#  'the measuring of technology reception in the use ofinformation system of regional library by using modeltechnology acceptence model tam',
#  'survei ereadiness infrastruktur guru tinggi yogyakarta kuliah bas elearning',
#  'solusi obat produk klink sistem pakar',
#  'sistem gaji kantor balai konservasi borobudur bas clientserver',
#  'sistem kenal jenis kayu guna principal components analysis',
#  'sistem kelola promosi barang bas website guna metode analytical hierarchy prosess studi kasus magaswalayan yoyakarta',
#  'sistem aman distribusi software sms gateway',
#  'sistem terima siswa baru studi kasus smkn  pringgabaya lombok timur ntb',
#  'sistem tentu kait skripsi dasar keyword seeking studi kasus pustaka universitas ahmad dahlan',
#  'sistem dukung putus untuk pilih lokasi buka cabang usaha variasi mobil metode promethee tudi kasus usaha variasi mobil anfa',
#  'sistem dukung putus untuk tentu supplier baik guna metode weighted product',
#  'sistem dukung putus untuk tentu peringkat sekolah sma kota yogyakarta bas web',
#  'sistem dukung putus untuk tentu kualitas jamur',
#  'sistem dukung putus untuk tentu hama sakit tanam holtikultura komoditas sayur metode case base reasoning bas web',
#  'sistem dukung putus seleksi calon karyawan metode promethee studi kasus pamella group yogyakarta',
#  'sistem dukung putus nilai kualitas jenis kayu untuk jadi ukir furniture guna kriteria bayea',
#  'sistem dukung putus tentu lokasi diri counter handphone serta tunjuk lokasi geografis kota yogyakarta',
#  'sistem dukung putus tentu lokasi budidaya jamur tiram metode kriteria bayes',
#  'sistem dukung putus tentu sesuai jenis lahan untuk budidaya tanam buah guna metode similarity bas web',
#  'sistem dukung putus tentu daerah cemar limbah home industri bas sig',
#  'sistem dukung putus tentu daerah demam darah dengue dbd provinsi daerah istimewa yogyakarta guna kriteria bayes',
#  'sistem dukung putus tentu calon tugas haji metode simple additive weighthing',
#  'sistem dukung putus pilih lokasi warnet metode ahp studi kasus green net',
#  'sistem dukung putus tentu kerja dasar tes pribadi bas web',
#  'sistem dukung putus klinis untuk efisien diagnosa sakit jiwa guna case based reasonning',
#  'sistem cari lokasi lampu lintas pt qumicom indonesia bas web',
#  'sistem nalar bas kasus untuk mendiagnosa sakit gigi mulut',
#  'sistem ajar interaktif materi pokok lensa bas multi media untuk siswa sma kelas xi',
#  'sistem pakar untuk tentu tolong pertama celaka bas mobile',
#  'sistem pakar untuk diagnosis sakit kasus bedah umum guna metode dempstershafer',
#  'sistem pakar untuk mendiagnosa sakit tanam pangan guna certainty factor',
#  'sistem pakar untuk mendiagnosa sakit tular hewan manusia zoonosis guna metode demste shafer',
#  'sistem pakar untuk mendiagnosa sakit kambing etawa bas web',
#  'sistem pakar deteksi sakit kelamin bas wireles application protocol teorema bayes',
#  'sistem pakar tentu hama sakit tanam palawija',
#  'sistem pakar mendiagnosa rusa sepeda motor guna metode teorema bayes',
#  'sistem pakar bas web untuk diagnosa sakit sapi',
#  'sistem otentikasi user jaring wireles bas web server linux',
#  'sistem konsultasi uang tentu terima pinjam lkm lembaga uang mikro guna metode kneares neighbor',
#  'sistem integrasi data untuk mudah tukar informasi obat klinik sehat bas web service',
#  'sistem identifikasi citra rimpang tanam famili zingiberaceae temu guna metode fungsi jarak one minus correlation coefficient',
#  'sistem diagnosa tumbuh kembang anak representasi tahu jaring semantik',
#  'sistem riwayat kompetensi mahasiswa bas web service studi kasus program studi teknik informatika',
#  'sistem tentu rencana laksana program imunisasi serta peta geografis sudi kasus dinas sehat kab wonosobo',
#  'sistem tentu mahasiswa prestasi lingkung kopertis v metode kriteria bayes bas multi user',
#  'sistem dukung putus seleksi terima beras untuk keluarga miskin guna metode simple additive weighting',
#  'sistem dukung putus untuk tentu diagnosis sakit hewan ternak guna metode case base reasoning',
#  'sistem dukung putus untuk lacak cenderung bakat anak',
#  'sistem dukung putus amal minta geplak guna metode exponential smoothing studi kasus pabrik geplak cinta rasa dusun tirto triharjo pandak',
#  'sistem dukung putus seleksi posisi main sepak bola studi kasus klub bola ps kalas',
#  'sistem dukung putus tentu status gizi balita',
#  'sistem dukung putus tentu posisi main olahraga bola voli',
#  'sistem dukung putus tentu terima jamin sehat masyarakat untuk masyarakat miskin guna kriteria bayes studi kasus dinas sehat kabupaten kulon progo',
#  'sistem dukung putus tentu terima beasiswa sekolah tengah pertama smp guna kriteria bayes studi kasus smp negeri  pandak bantul',
#  'sistem dukung putus tentu lokasi bts guna metode bayes',
#  'sistem dukung putus tentu kualitas sdm karyawan pt madu baru yogyakarta',
#  'sistem dukung putus tentu kualitas kayu untuk rajin meubel',
#  'sistem dukung putus tentu kualitas jenis kulit hewan untuk rajin kulit dekat sistem pakar',
#  'sistem dukung putus tentu layak lokasi diri klinik',
#  'sistem dukung putus tentu layak bus kota bas web kriteria bayes',
#  'sistem dukung putus tempat tenaga sehat',
#  'sistem dukung putus pilih lokasi untuk kawasan rumah kabupaten bantul yogyakarta bas web',
#  'sistem dukung putus pilih guru prestasi tingkat sma kota yogyakarta guna kriteria bayes bas client server',
#  'sistem dukung putus pilih bidang minat mahasiswa teknik informatika metode profile matching bas web',
#  'sistem dukung putus klinis untuk diagnosa sakit kandung bas case base reasoning dekat sistem pakar',
#  'sistem dukung putus sehat untuk derita penyalit diabetes mellitus komplikasi bas wap wireless application protocol',
#  'sistem dukung putus meta untuk tingkat ekonomi bas industri',
#  'sistem dukung putus nilai kerja pegawai untuk naik jabat guna metode gap kompetensi',
#  'sistem dukung putus pilih lokasi bengkel metode promethee',
#  'sistem dukung putus barang layak promosi minimarket studi kasus pamella swalayan yogyakarta',
#  'sistem deteksi sakit ikan gurame guna jaring syaraf tiru metode backpropagation',
#  'sistem daftar layan sehat dokter praktek bas sms gateway',
#  'sistem cari jalur pendek trayek bus transjogja',
#  'sistem nalar bas kasus untuk sakit tular nyamuk',
#  'sistem mesan tiket tanding sepak bola bas short messages services',
#  'sistem mesan taksi guna layan bas lokasi',
#  'sistem pantau ditribusi sedia barang bas intraweb cv citra putra mandiri lampung',
#  'sistem lacak kendara bas opengts pt panji sekar yogyakarta',
#  'sistem pakar untuk mendiagnosa sakit lambung implementasi metode cbr casebased reasoning bas web',
#  'sistem pakar tentu jenis awat wajah studi kasus rs pku muh yogyakarta',
#  'sistem pakar untuk identifikasi sakit udang galah metode theorema bayes',
#  'sistem pakar untuk diagnosis sakit ganggu tidur bas web guna metode certainty factor',
#  'sistem pakar untuk diagnosis rusa kamera digital',
#  'sistem pakar untuk mendiagnosa sakit salur nafas paru guna metode certainty factor',
#  'sistem pakar untuk mendiagnosa sakit salur cerna guna metode dempster shafer',
#  'sistem pakar untuk mendiagnosa sakit usus manusia guna metode case based reasoning',
#  'sistem pakar untuk mendiagnosa sakit tanam serealia',
#  'sistem pakar untuk mendiagnosa sakit tanam palawija bas web',
#  'sistem pakar untuk mendiagnosa sakit tanam jamur metode certainty factor',
#  'sistem pakar untuk mendiagnosa sakit kelinci metode certainty factor',
#  'sistem pakar untuk mendiagnosa sakit ikan hias bas web',
#  'sistem pakar untuk mendiagnosa sakit hewan mamalia',
#  'sistem pakar untuk mendiagnosa sakit lambung guna metode teorema bayes',
#  'sistem pakar untuk mendiagnosa sakit kelinci bas web',
#  'sistem pakar untuk mendiagnosa hama sakit tanam bawang merah guna certainty factor',
#  'sistem pakar untuk identifikasi sakit umum bas web',
#  'sistem pakar untuk diagnosa sakit tular hewan lalat manusia bas web metode theorema bayes',
#  'sistem pakar tentu obat antihipertensi derita sakit komplikasi metode dempster shafer',
#  'sistem pakar tentu sesuai lahan tani untuk pembudidayaan tanam buah',
#  'sistem pakar mendiagnosa sakit ikan air tawar bas website',
#  'sistem pakar mendiagnosa sakit buah pasca panen',
#  'sistem pakar mendiagnosa jenis sakit stroke guna metode certainty factor',
#  'sistem pakar diagnosa sakit skizofrenia guna metode demsptershafer bas web',
#  'sistem pakar diagnosa sakit napas manusia bas web metode tsukamoto',
#  'sistem pakar diagnosa sakit kanker terap dempstershafer teori',
#  'sistem pakar diagnosa lain tumbuh bayi masa kandung',
#  'sistem pakar bas web untuk mendiagnosa sakit unggas guna teorema bayes',
#  'sistem monitoring pecah masalah bimbing konseling siswa mts n gubuk rubuh wonosari',
#  'sistem laboratorium sdit luqman al hakim yogyakarta guna analisis zachman framework',
#  'sistem konsultasi diagnosa rusa modifikasi sepeda motor matic',
#  'sistem identifikasi citra jahe zingiber officinale guna metode jarak czekanowski',
#  'sistem broadcase proses ajar ajar synchronous asynchronous',
#  'sistem administrasi huni kost wilayah studi kasus rw  janturan umbulharjo yogyakarta',
#  'simulasi pilih rute pendek algoritma djikstra guna macromedia flash mx',
#  'simulasi proses enkripsi dekripsi algoritma rijndael untuk dukung proses ajar kriptografi bas web',
#  'simulasi bayar tiket tanding sepak bola bas wap',
#  'segmentasi citra medik mri magnetic resonance imaging guna metode region threshold',
#  'segmentasi citra kanker serviks guna metode kmeans clustering region growing',
#  'spk pilih lokasi pabrik metode browngibson',
#  'sistem resevasi hotel basis mobile aplication guna java midlet mysql',
#  'sistem olah aset desa administrasi desa bas web',
#  'sistem dukung putus tentu lokasipembangunan tower base transceiver station bts guna kriteria bayes serta letakgeografisnya',
#  'sistem dukung putus pilih program studi mahasiswa baru universitas ahmad dahlan yogyakarta guna metode topsis',
#  'sistem dukung putus tentu menang jasa borong proyek metode kriteria bayes studi kasus dinas kerja umum kabupaten tanggung',
#  'sistem pakar untuk diagnosa komplikasi ibu janindimasa hamil bas mobile',
#  'sistem pakar bas web untuk identifikasi sakit hewan pelihara',
#  'segmentasi citra batik sasambo dasar fitur tekstur guna metode filter gabor mean shift clustering',
#  'rekayasa aplikasi olah data barang berbasiska basis data pt indomarco adi prima tasikmalaya',
#  'rancangn bangun sig pantau sebar sakit dbd kabupaten siak bas web',
#  'rancang bangun sistem pakar untuk mendiagnosa rusa mesin kapal laut',
#  'rancang bangun sistem monitoring terapi arv antiretroviral metode client server bas smartphone rsup dr sardjito',
#  'rancang bangun aplikasi marketplace restoran yogyakarta bas web online',
#  'rancang bangun aplikasi enkripsi dekripsi sms short message service mobile algoritma adfgvx aproduct cipher bas jme',
#  'rancang bangun sistem dukung putus tentu urut personil haji umroh biaya dinas studi kasus universitas ahmad dahlan uad',
#  'rancang bangun web sistem kelola zakat bas rich internet application',
#  'rancang bangun web service aplikasi management event acara',
#  'rancang bangun visualisasi model tigadimensi tata surya bas teknologi augmented reality',
#  'rancang bangun ui user interface ux user experience aplikasi manajemen skripsi program studi teknik informatika uad',
#  'rancang bangun sistem dukung putus tempat guru wali kelas bas kasus',
#  'rancang bangun sistem layan bas lokasi untuk mobile marketing produk usaha mikro tengah umkm manfaat konsep intelligent resource monitor irm',
#  'rancang bangun sistem hotspot guna captive portal',
#  'rancang bangun model secret sharing guna kriptografi cipher block chaining',
#  'rancang bangun digital library multiserver teknologi web service',
#  'rancang bangun aplikasi website ecommerce desain interior eksterior cv graha anggun abadi',
#  'rancang bangun aplikasi web untuk bantu proses ajar mahasiswa teknik informatika uad matakuliah matematika diskret materi kombinatorik',
#  'rancang bangun aplikasi traffic counter manfaat radio frequency identification rfid',
#  'rancang bangun aplikasi model kuesioner nilai aktivitas ajar dosen mahasiswa',
#  'rancang bangun aplikasi mobile chat room guna koneksi bluetooth',
#  'rancang bangun aplikasi game dam daman guna lestari main tradisional',
#  'rancang bangun aplikasi business intelligence uji kerja unit guna metode balanced scorecard studi kasus bagi antar mail processing center pt pos indonesia semarang',
#  'rancang bangun aplikasi android specialist interest group sig teknik informatika universitas ahmad dahlan yogyakarta guna metode google google cloud messaging',
#  'rancang bangun metode kriptografi hybrid untuk aman dokumen digital',
#  'prototype internet radio broadcasting',
#  'proses dampak hasil seo onpage offpage pagerank index visitor untuk fresh website',
#  'program bantu ajar bangun geomatri siswa sd',
#  'prediksi konsumsi listrik ikm winner glove guna metode backpropagation',
#  'prediksi studi mahasiswa s teknik informatika universitas ahmad dahlan dasar prestasi akademik guna metode native bayes',
#  'beda problem focused coping hadap tugas kuliah tinjau jenis kelamin mahasiswa jurus teknik informatika uad yogyakarta',
#  'beda sikap pecah masalah mahasiswa prodi psikologi mahasiswa prodi teknik informatika universitas ahmad dahlan yogyakarta',
#  'banding metodologi web application frame work cake php codeigniter yii',
#  'banding metode inner product cosine similarity buat sistem identifikasi citra jenis rosella',
#  'perangkat lunak bantu untuk ajar kenal pahlawan indonesia untuk anak sekolah dasar',
#  'perangkat lunak bantu ajar kenal satwa indonesia untuk anak sekolah dasar',
#  'ancang sistem dukung putus tentu rumah sehat',
#  'ancang prototipe aplikasi sistem pakar mendiagnosa sakit tanam tani organik bas web metode bayes',
#  'ancang program ajar daardasar fotografi guna elearning',
#  'ancang perangkat lunak ajar struktur data pohon ekspresi expression tree studi kasus universitas ahmad dahlan yogyakarta',
#  'ancang enterprise architecture kerangka kerja zachman kantor wilayah menteri agama diy',
#  'ancang implementasi film animasi d sholihuun bas software open source',
#  'ancang implementasi topik latih susun paraagraf bahasa indonesia untuk sdkelas v studi kasus sdit lukman alhakim',
#  'ancang implementasi bahasa pemrograman algoena guna notasi algoritma',
#  'ancang sistem pakar untuk deteksi hama sakit tanam cengkeh bas website',
#  'ancang sistem monitoring bandwidth internet bas sms',
#  'ancang model tata kelola teknologi informasi xyz indonesia bas cobit  ',
#  'ancang model tata kelola teknologi informasi bas cobit   proses kelola sumber daya manusia it studi kasus bagi kelola data kab kendal',
#  'ancang model enterprise resource planning erp studi kasus pt madubaru',
#  'ancang enterprise resource planning badan uang akuntansi pt xyz',
#  'ancang enterprise architecture planning eap proses manajemen aset zachman framework studi kasus divisi manajemen fasilitas pt xyz',
#  'ancang emall media informasi beli buku bas wap',
#  'ancang elibrary pustaka sekolah dasar untuk sedia referensi ajar siswa guna web service',
#  'ancang implementassi metode ajar kriptografi md message digest ',
#  'ancang implementasi web ecommerce mesan jual fashion bal island',
#  'ancang implementasi sistem ajar bahasa indonesia topik kata imbuh untuk sd kelas v studi kasus sdit lukman al hakim yogyakarta',
#  'ancang implementasi ajar kali bagi bilang untuk sekolah dasar kelas  studi kasus sd it lukman al hakim yogyakarta',
#  'ancang implementasi msev manager system electronic voucher software aplikasi isi pulsa elektrik object oriented development',
#  'ancang aplikasi kontruksi dinding tahan tanah jenis dinding grafitasi gravity wall',
#  'ancang implementasi sekuriti sistem empney infrastruktur sms over gprs',
#  'tingkat mutu kontras intensitas citra digital guna gabung teknik geser teknik lebar histogram',
#  'ukur kerja selesai sistem sama linier guna metode eliminasi gauss gaussjordan matriks invens dekomposisi lu',
#  'ukur ereadiness dosen universitas ahmad dahlan kuliah bas elearning',
#  'ukur ereadiness mahasiswa terap elearning uad yogyakarta',
#  'ukur ereadiness mahasiswa yogyakarta kuliah bas elearning',
#  'ukur ereadiness dosen yokyakarta kuliah bas elearning',
#  'ingat otomatis aotomatic reminder bas sms untuk nasabah usaha pegasaian',
#  'guna aplikasi sms untuk manajemen inventory perusahaanstudi kasus cv gunung jati distributor keramik wilayah jawa tengah',
#  'guna algoritma asosiasi apriori untuk cari hubung aktif kelulus karir mahasiswa',
#  'kembang web service oauth   web portal studi kasus modul kerja praktik portal program studi teknik informatika universitas ahmad dahlan',
#  'kembang user experience website design guna kansei engineering teknologi flat and adaptive clothing store untuk tingkat mudah nyaman guna',
#  'kembang sistem tentu jabat struktural tempat wali kelas smk batur jaya  ceper klaten',
#  'kembang modul enkripsi deskripsi pemrograman php metode cbc modifikasi',
#  'kembang media konsultasi diagnosa sakit ginjal salur kemih manfaat metode teorema bayes bas web',
#  'kembang komponen ocx untuk buat label barcode guna metode code  aplikasi',
#  'kembang aplikasi sistem pakar mendiagnosa sakit hewan pelihara bas mobile',
#  'kembang aplikasi jaring saraf tiru mendiagnosa sakit epilepsi metode hebb rule delta rule',
#  'kembang aplikasi generator modul cms lokomedia untuk mudah kembang sistem bas web',
#  'kembang animasi suluh siaga bencana gempa bumi guna metode frame by frame tweening',
#  'kembang website aditv metode embed video guna teknologi html',
#  'kembang sistem pustaka online sekolah muhammadiyah yogyakarta bas web service',
#  'kembang sistem dukung putus untuk lanjut kontrak kerja karyawan cetak studi kasus cetak muhammadiyah surya sarana grafika',
#  'kembang sistem pakar troubleshooting komputer bas web',
#  'kembang sistem komplain bas web',
#  'kembang sistem inventarisasi seni budaya urus pusat muhammadiyah',
#  'kembang sistem administrasi sekolah bas web studi kasus sma taman madya ibu pawiyatan tamansiswa yogyakarta',
#  'kembang modul php barcode generator',
#  'kembang modul enkripsi dekripsi php modifikasi metode kriptografi cipher block chaining vigenere cipher implementasi kasus geekybyte com',
#  'kembang media ajar guna tanda baca siswa kelas v sd it luqman al hakim',
#  'kembang kualitas layan website guna metode analisis webqual  ',
#  'kembang game susun angka untuk jembatan anak usia ajar hitung tk tat twam asi',
#  'kembang implementasi algoritma cipher block chaining row transposition',
#  'kembang aplikasi sistem ukur compeency level index bas web studi kasus perum hutan kantor unit iii',
#  'kembang aplikasi sistem pakar untuk diagnosa sakit anak guna metode dempster shafer bas web',
#  'kembang aplikasi mobile web cakap bahasa korea bas lokasi guna foursquare api',
#  'kembang aplikasi metopen bas web program studi teknik informatika universitas ahmad dahlan',
#  'kembang aplikasi lagidimana bas android',
#  'kembang antivirus bas local area network lan server',
#  'ambang perangkat lunak bantu cari ruang ada selesai masalah dekat cerdas buat',
#  'aman database mysql web serang sql injection',
#  'terjemah bahasa indonesia melayu rok lengkap periksa kalimat ambigu bas web',
#  'terap web service untuk sistem nilai kuliah kerja nyata universitas ahmad dahlan',
#  'terap sistem aman honeypot ids jaring nirkabel hotspot',
#  'terap olap online analytical process pasien rawat jalan rumah sakit tudi kasus rskaia pku muhamadiyah kotagede yogyakarta',
#  'meta fasilitas umum sarana sehat kota yogyakarta guna google maps api',
#  'pembutan model crm customer relationship management xt square yogyakarta',
#  'buat rencana arsitektur enterprise badan kerjasama tanam modal bkpm propinsi diy bas soa service oriented architecture',
#  'buat model tata kelola ti bidang layan haji kantor menteri agama kota yogyakarta bas cobit  ',
#  'buat model supply shain management cv artha wibisono',
#  'buat model rencana strategis kembang ecoverment studi kasus dinas laut ikan diy',
#  'buat model rencana strategis si ti bidang selenggara haji umrah kantor wilayah menteri agama daerah istimewa yogyakarta',
#  'buat model rencana strategi kembang si ti rumah sakit zachman framework studi kasus rumah sakit umum daerah wonosari',
#  'buat model layan service akademik mahasiswa guna kerangka manajemen layan itil v  universitas ahmad dahlan',
#  'buat model enterprise resource planning kantor dinas tahan pangan kabupaten klaten',
#  'buat model customer relatioship management crm e government kominfo diy',
#  'buat model customer relationship management crm donq donuts',
#  'buat model customer relation management crm pt naturindo fresh',
#  'buat model si ti terbit buku amara books guna kerangka kerja zachman',
#  'buat model crm customer relationship management bagi hubung dishubkominfo diy',
#  'buat enterprise architecture planning guna kerangka kerja zachman studi kkasus impinan pusat muhammadiyah',
#  'buat enterprise architecture planning kerangka kerja zachman koperasi mahasiswa uad yogyakarta',
#  'buat enterprise architecture planning dinas budaya provinsi diy guna kerangka zachman',
#  'buat action plan kembang egovernment dishubkominfo',
#  'buat transliterator aksara jawa guna ibus input framework ekspresi reguler',
#  'buat program aplikasi transliterator teks bahasa jepang huruf latin jadi japanese kana hiragana katakana',
#  'buat rencana arsitektur enterprise teknologi informasi lembaga latih kembang softskill metode zachman framework studi kasus universitas xyz',
#  'buat model tata kelola it untuk proses akademik guna cobit   studi kasus universitas xyz',
#  'buat model sistem mgovernment studi kasus perintah kota yogyakarta',
#  'buat model sistem enterprise resource planning panti sosial pamardi putra provinsi diy',
#  'buat model si ti cobit   kerangka kerja zachman kantor tahan pangan kab klaten',
#  'buat model rencana strategis si ti homestay venezia',
#  'buat model rencana strategis si ti studi kasus departemen akademik universitas xyz',
#  'buat model manajemen ubah kembang egovernment guna teori technology acceptance model tam studi kasus dinas perindagkop provinsi diy',
#  'buat model manajemen ubah kembang egovernment dinas tani provinsi diy',
#  'buat model enterprise resource planning dinas sehat provinsi diy',
#  'buat model enterprise architecture planning btn surya umbulharjo togaf architecture development method bagi himpun biaya',
#  'buat model customer relationship management crm egovernment dinas laut ikan diy',
#  'buat model customer relationship management crm dinas industri dagang koperasi usaha tengah studi kasus dinas perindakop provinsi diy',
#  'buat model customer relationship management crm dinas sehat kota yogyakarta',
#  'buat model customer relationship management crm dinas sehat diy guna delivery and support ds',
#  'buat game edukatif tata tertib lintas untuk anak usia',
#  'buat enterprise arsitecture planning guna kerangka zachman majelis pustaka informasi pp muhammadiyah yogyakarta',
#  'buat enterprise architecture planning kerangka kerja zachman majelis didik tinggi pp muhammadiyah yogyakarta',
#  'buat enterprise architecture planning eap lembaga tanggulang bencana pimpin pusat muhammadiyah yogyakarta guna kerangka kerja zachman',
#  'buat enterprise architectur planning kantor universitas urus internasional kerangka kerja zachman',
#  'buat e commerce templates media informasi pasar studi kasus seagara itc distributor',
#  'buat aplikasi transliterator translator bahasa batak',
#  'buat aplikasi supply chain management bas web service untuk bantu distribusi batik guna php mysql',
#  'buat aplikasi baca shalat wajib doa shalat teknik on over mouse',
#  'ajar metode kriptografi block transposition row trasposition bas web',
#  'bangun pusat informasi obat untuk mudah cari data obat masyarakat bas information retrieval',
#  'bangun web proxy mikrotik untuk dukung internet sehat smk muhammadiyah  patuk gunungkidul',
#  'bangun web monitoring cbt guna sistem basis data distribusi sistem computer based test ukdgi uji kompetensi dokter gigi indonesia',
#  'bangun sistem cari lokasi geolocation dasar gps bas mobile web studi kasus cari lokasi hotel yogyakarta',
#  'bangun sistem cari lokasi kuliner yogyakarta geolocation dasar gps bas mobile web',
#  'bangun online shop guna jee studi kasus toko karya cipta furniture jepara',
#  'manfaat webcam sistem pantau ruang kuliah bas web studi kasus uad yogyakarta',
#  'manfaat teknik tweening character library buat film animasi pendek indah beda teman',
#  'beda motivasi selesai skripsi mahasiswa kerja mahasiswa kerja mahasiswa jurus teknik informatika universitas ahmad dahlan',
#  'ancang model si ti dekat supply chain management cv alas djogja',
#  'ancang analisis vpn virtual private network guna ltp layer  tunneling protocol ipsec ip security kantor pasar bpjs sehat yogyakarta',
#  'kembang web profil cv baitusoft guna framework ci',
#  'meta pariwisata yogyakarta guna google map sistem android mobile pandu wisata',
#  'buat model enterprise resource planning erp pada xt square yogyakarta',
#  'buat model enterprise architecture planning eap unit sinyal telekomunikasi listrik sintelis pt kereta api indonesia persero daop  yogyakartaberbasis zachman framework',
#  'otomatisasi pisah bandwith iix indoneia internet exchange ix intternet exchange guna mikrotik routeros',
#  'optimasi frame rate game kembang fps creator',
#  'optimasi raw material untuk tekan biaya buat beton siap pakai ready mix studi kasus pt patsean sumber rejeki',
#  'optimasi simpan cache guna coss cyclic object storage system studi kasus smp muhammadiyah  yogyakarta',
#  'optimalisasi simpan video guna viseocache proxy server',
#  'optimalisasi website fakultas teknologi industri universitas ahmad dahlan sesuai algoritma google panda penguin',
#  'optimalisasi aman jaring lan local area network di smk n  wonosari',
#  'optimasi kerja jaring guna metode scheduler studi kasus laboratorium jaring universitas ahmad dahlan',
#  'model sistem dukung putus nilai layak beri kredit',
#  'model tentu status gizi balita puskesmas',
#  'mobile application guna personal digital assistance pda untuk dukung layan unjung restoran',
#  'bangun sistem lacak barang cara realtime bas mobile push notification',
#  'bangun image editor online hubung facebook api',
#  'bangun game education saringman guna tanam bersih anak',
#  'bangun aplikasi e learning fkip universitas muhammadiyah purworejo',
#  'bangun aplikasi autogenerate script flowchart untuk dukung business process reengineering',
#  'bangun sistem vrrp virtual router redundancy protocol guna sistem operasi freebsd studi kasus laboratorium jaring uad',
#  'bangun sistem integrasi bas web sdit luqman alhakim',
#  'bangun sistem buat resep obat untuk cegah palsu teknik code generator bas web',
#  'bangun eshop untuk rajin kulit manding yogyakarta guna framework codeigniter',
#  'bangun basis tahu untuk mendiagnosa sakit kelamin model nalar bas kasus case based reasoning',
#  'bangun aplikasi ajar sederhana fungsi boolean metode quinemccluskey',
#  'bangun aplikasi layan informasi langgan pdam bas sms studi kasus pdam tirtamarta kota yogyakarta',
#  'media ajar pecah sederhana guna pecah masalah untuk sekolah dasar sd kelas  studi kasus sdit lukman al hakim yogyakarta',
#  'media ajar hitung determinan reduksi minor ekspansi kofaktor adjoin',
#  'media ajar materi baik kualitas citra mata kuliah olah citra',
#  'media ajar materi context free grammar mata kuliah teori bahasa otomata',
#  'media ajar bahasa indonesia tentu tema topik cerita untuk sekolah dasar kelas  studi kaus sdit lukman al hakim yogyakarta',
#  'media ajar algoritma kriptografi product cipher modifikasi',
#  'media konsultasi untuk sakit salur nafas manusia guna metode case base reasoning',
#  'media ajar guna ukur waktu panjang berat pecah masalah untuk sekolah dasar sd kelas ',
#  'media ajar bas komputer mata ajar matematika bilang untuk sekolah dasar kelas iii sudi kasus sd it lukman al hakim yogyakarta',
#  'media ajar aplikasi jarimatika tambah kurang untuk anak bas mutimedia',
#  'media layan informasi pajak bumi bangun bas jquery mobile kabupaten sleman',
#  'media konsultasi tentu sakit balita solusi herbal bas kasus',
#  'manajemen paket ubuntu linux repository server bas lighttpd   ',
#  'managemen ruang pasien rawat inap rs pku muhammadiyah yogyakarta teknologi java studi kasus rumah sakit pku muhammadiyah jl kh ahmad dahlan yogyakarta',
#  'majalah elektronik sekolah bas web mts al mahalli pleret bantul',
#  'media dukung ajar proses enkripsi dekripsi algoritma cryptography cbc vigenere chiper block transposition cbc modifikasi aman file teks data teks',
#  'location based service rental dasar info cd untuk cepat user cari judul cd',
#  'layan jual produk fitnes victory fitness center bas web guna aplikasi aura cms',
#  'layan informasi lokasi event guna location based service lbs bas jquery mobile',
#  'jaring syaraf tiru backpropagation untuk diagnosa sakit hepatitis',
#  'jaring syaraf tiru backpropagation untuk diagnosa hipertensi stroke',
#  'informasi layan manasik haji bas web',
#  'indie net labels bas web',
#  'implementasi staging animasi perilaku konsumsi makan sehat',
#  'implementasi sistem aman data guna algoritma tea aplikasi elearning',
#  'implementasi proxy server load balancing guna metode connection classifier pcc bas mikrotik',
#  'implementasi metode interpolasi linier untuk identifikasi keruh air pemrosesan awal pelembuyan citra studi kasus pdam tirtamarta yogyakarta',
#  'implementasi metode canny untuk deteksi tepi mutu daun tembakau',
#  'implementasi kriptografi kunci publik elgamal untuk proses enkripsi dekripsi guna aman file data',
#  'implementasi aman data guna algoritma blowfish lsb citra',
#  'implementasi jaring syaraf tiru perceptron untuk tentu tokoh wayang',
#  'implementasi expert system untuk diagnosis sakit mata guna dhempster shafer',
#  'implementasi case base reasoning sistem pakar tentu jenis ganggu jiwa',
#  'implementasi back office aplikasi mgoverment studi kasus perintah kota yogyakarta',
#  'implementasi web service sirkulasi pustaka guna data base distribusi',
#  'implementasi web service guna simple object access protocol studi kasus afiliasi amazon com',
#  'implementasi wap mesan tiket bis',
#  'implementasi virtual reality vr d hotel merak indah klaten',
#  'implementasi virtual private network vpn untuk aman komunikasi data jaring bas wireless',
#  'implementasi transformasi wavelet pemrosesan awal sistem kenal wajah citra digital',
#  'implementasi teknik untuk kompresi citra digital',
#  'implementasi teknik character animation teknik masking buat film animasi jujur',
#  'implementasi sistem pakar untuk obat bekam metode case base reasioning',
#  'implementasi sistem pakar untuk mendiagnosa sakit manusia guna metode dempster shafer',
#  'implementasi sistem management user hotspot guna freeradius coovachilli studi kasus biskom universitas ahmad dahlan',
#  'implementasi network monitoring untuk tingkat kerja jaring studi kasus laboratorium jaring uad',
#  'implementasi metode limited cut post planning animation buat film animasi bersih bagi iman',
#  'implementasi manajemen bandwidth guna hierarchical token bucket htb sistem operasi linux studi kasus laboratorium jaring uad',
#  'implementasi manajemen bandwidth web proxy guna clearos smk n  asih',
#  'implementasi aman data guna algoritma gost steganografi citra',
#  'implementasi image watermarking citra digital guna teknik discrete fourier transform dft singular value decomposition svd',
#  'implementasi image watermarking citra digital discrete wavelet transform dwt daubechies d',
#  'implementasi honeypot untuk tingkat aman jaring bas wireless',
#  'implementasi grafika komputer followthruough and overlapping actions buat film kartun nilai nilai ikhlas',
#  'implementasi ecommerce untuk jual buku terbit ombak bas framework',
#  'implementasi case based reasoning untuk mendiagnosa sakit paru manusia',
#  'implementasi case based reasoning sistem pakar diagnosa sakit kanker bas web',
#  'implementasi algoritma kriptografi simetri aes asimetri elgamal dokumen microsoft office',
#  'identifikasi iris mata manusia jaring saraf tiru',
#  'implementasi majalah dinding platform android',
#  'hubung tingkat tahu bahaya rokok perilaku rokok pd mahasiswa teknik informatika uad yogyakarta',
#  'game edukasi tingkat daya ingat anak main modo modi',
#  'game edukasipengenalan rambu lintas untuk anak usia studi kasus tk asyiah bustanul athfal janturan',
#  'game adventure guna metode side scrolling cerita rakyat doyan nada untuk tingkat paham budayasasak lombok anak',
#  'front system guna mgovernment untuk tingkat interaksi masyarakat perintah yogyakarta',
#  'enterprise arsitectur planning produksi gula zachman framework',
#  'embedded graphic online service',
#  'ereadiness buat model sistem mgovernment studi kasus perintah kota yogyakarta',
#  'diagnosa rusa printer dekat sistem pakar guna metode theorema bayes bas web',
#  'deteksi sakit tulang guna jaring syaraf tiru metode backpropagation',
#  'deteksi sakit serang hama tanam buah salak guna jaring syaraf tiru jst metode perceptron',
#  'deteksi sakit ayam guna jaring syaraf tiru metode perceptron',
#  'deteksi sakit salur nafas jaring syaraf tiru metode perceptron',
#  'deteksi sakit autis jaring syaraf tiru algoritma perceptron',
#  'deteksi cacat gerabah guna metode canny',
#  'deteksi jenis ikan hias guna metode canny',
#  'deteksi perilaku simpang seksual guna metode fordward chaining bas web',
#  'desain implitasi sms gateway untuk layan hasil studi mahasiswa studi kasus prodi teknik informatika informatika uad',
#  'desain implementasi jejaring sosial gemar sepak bola bas web',
#  'desain implementasi virtual server guna proxmox',
#  'desain impelementasi ecounseling program studi bimbing konseling studi kasus program bimbing konseling uad yogyakarta',
#  'desain implementasi web ecommerce mesan buku cara online studi kasus divaprees publisher',
#  'decision support system nilai kerja guru dasar standar kurikulum tingkat satu didik ktsp',
#  'computer based training teknik rancang bangun guna aplikasi autocad',
#  'bank lokasi fasilitas umum kota yogyakarta bas web service',
#  'arsitektur teknologi informasi komunikasi guna framework zachman studi kasus biro finansial aset bifas universitas xyz',
#  'aplikasikartu nama virtual virtual business card bas web mobile',
#  'aplikasi terjemah bahasa indonesia bahasa batak angkola bas android',
#  'aplikasi terjemah bahasa indonesiaseraway serawayindonesia',
#  'aplikasi sistem dukung putus tentu tingkat epidemi puskesmas induk umbulharjo i kota yogyakarta',
#  'aplikasi sistem pakar untuk diagnosa medis sakit sistem edar darah guna metode case based reasoning',
#  'aplikasi sistem pakar bas web untuk diagnosa sakit tanam kelapa guna metode certainty factor serta gejala citra',
#  'aplikasi sistem pakar bas web untuk diagnosa sakit tanam kelapa guna metode certainly factor serta gejala citra',
#  'aplikasi penterjemah untuk bahasa indonesia bahasa jawa',
#  'aplikasi penterjemah bahasa ogan  indonesia',
#  'aplikasi penterjemah bahasa indonesia bahasa lampung disertasi analisis sintaksis',
#  'aplikasi penterjemah bahasa indonesia bahasa komering',
#  'aplikasi olah citra untuk deteksi kualitas daging sapi dasar fitur tekstur bas histogram citra',
#  'aplikasi olah citra untuk deteksi tingkat matang semangka dasar fitur tekstur kulit buah',
#  'aplikasi olah citra guna metode thresholding untuk deteksi rusa gerabah',
#  'aplikasi tahu dasar hiv aids bas android',
#  'aplikasi terjemah bahasa indonesia bahasa banjar analisis sintaksis',
#  'aplikasi pemrosesan bahasa alami bahasa indonesia bahasa perintah dos',
#  'aplikasi metode region growing untuk monitoring tumbuh panjang kecambah',
#  'aplikasi game side scrolling jaka tarub  bidadari',
#  'aplikasi game arcade bajak laut bas java jme',
#  'aplikasi deteksi rusa cacat sambung las guna metode region growing',
#  'aplikasi bantu olah nilai indeks kerja dosen studi kasus fakultas teknologi industri uad',
#  'aplikasi android untuk media promosi publikasi jual mobil kota kalong metode android notification',
#  'aplikasi wap untuk kembang website pmi cabang kota yogyakarta',
#  'aplikasi web elearning media ajar alternatif sma studi kasus aplikasi web elearning sma negeri  rembang kabupaten purbalingga',
#  'aplikasi visualisasi model data struktur basis data',
#  'aplikasi uji coba toefl bas web smu muhammadiyah ii yogyakarta',
#  'aplikasi try out bahasa inggris untuk uji nasional sekolah tengah atas',
#  'aplikasi transliterator translator bahasa indonesia bahasa korea bahasa korea bahasa indonesia',
#  'aplikasi transformasi watershed untuk segmentasi citra spatial filter pemroses awal',
#  'aplikasi transformasi warna ycbcr untuk deteksi jenis warna kulit tomat fase matang tomat',
#  'aplikasi toko buku online bas sms gateway over gprs general packet radio service',
#  'aplikasi tes pribadi untuk tempat karyawan guna metode myersbriggs type indicator mbti bas web studi kasus pt winata putra mandiri',
#  'aplikasi tes pribadi guna metode edwars personal prefefence schedul studi kasus cv exist klaten jawa tengah',
#  'aplikasi tes intelligence quotient iq guna standar wechsler bas web',
#  'aplikasi terjemah untuk ajar bahasa jawa aksara jawa',
#  'aplikasi terjemah bahasa indonesiasunda bas wap wireless application protocol',
#  'aplikasi terjemah bahasa indonesia kebahasa ternate serta periksa kalimat ambigu',
#  'aplikasi terjemah bahasa indonesia bahasa tolak',
#  'aplikasi terjemah bahasa indonesia bahasa tidore serta analisis sintak',
#  'aplikasi terjemah bahasa indonesia bahasa jawa lengkap kece kalimat ambigu',
#  'aplikasi terjemah bahasa indonesia bahasa banyumas analisis teknik',
#  'aplikasi sumbang bina didik bas web integrasi sms gateway email server',
#  'aplikasi sistem tes online smp  ponjong gunungkidul',
#  'aplikasi sistem nilai kerja karyawan untuk naik jabat metode behaviourally anchored rating scale bars bas web',
#  'aplikasi sistem dukung putus tentu lokasi diri warnet metode analytical hierarchy process ahp studi kasus pt pika media komunika',
#  'aplikasi sistem dukung putus tentu lokasi bangun ruko metode naive bayes',
#  'aplikasi sistem pakar untuk mendiagnosa sakit hati saji jaring semantik',
#  'aplikasi sistem pakar untuk mendiagnosa sakit infeksi usus manusia',
#  'aplikasi sistem pakar untuk mendiagnosa ganggu kembang sehat anak metode certainty factor cf',
#  'aplikasi sistem pakar untuk diagnosa sakit tanam hias bas web guna teorema bayes',
#  'aplikasi sistem pakar tentu awat cantik bas web studi kasus pamella salon yogyakarta',
#  'aplikasi sistem pakar diagnosa infeksi sistem gastrousus saji jaring semantik',
#  'aplikasi sistem pakar diagnosa hama sakit tembakau guna teorema bayes',
#  'aplikasi short message service sms gateway layan informasi harga mesan makan bas sms',
#  'aplikasi sms gateway untuk reservasi hotel imperial aryaduta lippo karwaci',
#  'aplikasi sms gateway layan informasi santri wali santri pondok pesantren ibnul qoyyim',
#  'aplikasi sms gateway layan informasi jalur bis yogyakarta kira waktu tempuh dasar cepat rata bis bas sms',
#  'aplikasi sms microsoft visual basic mobile fbus   activex control',
#  'aplikasi sig untuk cegah interferensi stasiun pancar radio wilayah daerah istimewa yogyakarta',
#  'aplikasi puzzle game program bantu ajar',
#  'aplikasi program ajar sains sekolah dasar',
#  'aplikasi banding cari jalur pendek jaring syaraf tiru kohonen self organizing maps jaring syaraf tiru boltzmann machine',
#  'aplikasi baik citra digital untuk identifikasi rusa cacat film radiografi sambung las',
#  'aplikasi perangkat lunak awat kendara po maju lancar yogyakarta pemrograman delphi  ',
#  'aplikasi perangkat lunak gaji karyawan mirota gejayan',
#  'aplikasi penterjemah untuk bahasa indonesia bahasa cirebon',
#  'aplikasi penterjemah bahasa indonesiabahasa sunda bas sms',
#  'aplikasi jual voucher elektronik via komputer',
#  'aplikasi nilai kerja guru sd kepala sekolah kriteria bayes',
#  'aplikasi olah citra untuk deteksi mutu buah jeruk dasar rusa kulit jeruk guna metode thresholding',
#  'aplikasi olah citra deteksi kualitas cabai dasar tingkat matang guna transformasi warna ycbcr',
#  'aplikasi olah citra digital untuk tingkat cerah citra guna metode retinex',
#  'aplikasi olah citra digital untuk tentu tingkat mutu buah guna metode thresholding',
#  'aplikasi olah bahasa alami untuk bahasa indonesia bahasa karo',
#  'aplikasi konversi file teks rtf txt file suara wav',
#  'aplikasi kenal pola batik jogja dasar fitur tekstur guna metode jarak city block',
#  'aplikasi kenal citra rambu lintas bentuk lingkar guna metode jarak cityblock',
#  'aplikasi kelola uang pribadi bas android',
#  'aplikasi arsip bas web',
#  'aplikasi aman folder kunci simetrik algoritma blowfish',
#  'aplikasi terjemah bahasa indonesiabanjar banjarindonesia',
#  'aplikasi terjemah bahasa indonesia melayu rok',
#  'aplikasi tentu pajak bumi bangun studi kasus kantor layan pajak bumi bangun kabupaten kuningan  jawa barat',
#  'aplikasi deteksi rusa vespa',
#  'aplikasi daftar pasien obat via sms',
#  'aplikasi pemrograman visual basic   kendali hidup mati lampu bas pc atc',
#  'aplikasi ajar matematika satu waktu panjang berat untuk sekolah dasar sd kelas  studi kasus sd it lukman alhakim yogyakarta',
#  'aplikasi ajar matematika ukur berat untuk sekolah dasar sd kelas i studi kasus sdit lukman al hakim yogyakarta',
#  'aplikasi ajar kombinatorial prinsip dasar counting inklusieksklusi pigeonhole mata kuliah matematika diskrit',
#  'aplikasi ajar aksara jawa bas web',
#  'aplikasi pantau oleh suara partai politik pilih umum legislatif guna sms gateway studi kasus partai satu bangun provinsi diy',
#  'aplikasi layan adu masyarakat polisi sektor jogonalan klaten bas sms gateway',
#  'aplikasi mobile untuk media promosi iklan mesan iklan guna java  micro edition studi kasus skb daulat rakyat',
#  'aplikasi mobile sms gateway over gprs general packet radio service studi kasus swalayan madurejo piyungan yogyakarta',
#  'aplikasi mobile kumpul doa hari islam untuk mudah hafal doa bas android',
#  'aplikasi mobile commerce jual suplemen binaraga konsultasi bas wap studi kasus cakra sport center yogyakarta',
#  'aplikasi mobile commerce jual handicraft bas wap',
#  'aplikasi metode eigenfaces untuk kenal wajah',
#  'aplikasi metode discrete hartley transform dht untuk mampat citra',
#  'aplikasi manajemen uang pribadi bas web',
#  'aplikasi manajemen giat untuk organisasi nonprofit bas website',
#  'aplikasi medukasi layan bas lokasi kebun binatang gembira loka',
#  'aplikasi layan telepon bas voice xml sandang tuna netra',
#  'aplikasi layan informasi tagih mesan pasang baru lisrik pt pln diy guna wireless aplication protocol',
#  'aplikasi kriptografi untuk aman file guna algoritma twofish',
#  'aplikasi konsultasi siswa dekat sistem pakar studi kasus mtsn prambanansleman',
#  'aplikasi aman pesan guna algoritma steganografi metode least significant bit file bambar audio video',
#  'aplikasi katalog mesan buku social agency baru yogyakarta bas wap',
#  'aplikasi jaring syraf tiru backpropagation untuk diagnosa medis sakit sistem edar darah cardiovascular system',
#  'aplikasi jaring syaraf tiru untuk kenal pola angka guna metode hebb rule',
#  'aplikasi jaring syaraf tiru hopfield untuk kenal nilai uang kertas',
#  'aplikasi jaring syaraf tiru hopfield untuk diagnosa sakit tanam kelapa sawit',
#  'aplikasi jaring syaraf tiru bas web diagnosa sakit tanam cabai guna metode backpropagation',
#  'aplikasi jaring syaraf tiru backpropagation untuk deteksi rusa kendara sepeda motor',
#  'aplikasi inventori obat studi kasus pt budi makmur jayamurti',
#  'aplikasi informasi geografis untuk meta lokasi atm automated teller machine dasar lokasi obyek wisata bas web kota yogyakarta',
#  'aplikasi image morphing citra  dimensi guna metode field morphing',
#  'aplikasi general ledger untuk usaha multi company studi kasus pt cube computer indonesia',
#  'aplikasi game tradisional bas desktop main congklak',
#  'aplikasi game tradisional benthik bas dekstop',
#  'aplikasi game tembak perangkat mobile',
#  'aplikasi game wayang gatot kaca',
#  'aplikasi fast fourier transform fft untuk deteksi cacat citra tekstur kain batik',
#  'aplikasi expert system untuk mendiagnosa sakit lain darah guna metode teorema bayes',
#  'aplikasi expert system diagnosa sakit kandung guna theorema bayes',
#  'aplikasi enkripsideskripsi data microsoft word manfaat fungsi random delphi',
#  'aplikasi enkripsi sms metode vigenere bas jme',
#  'aplikasi enkripsi dekripsi sms algoritma aes mode operasi cbc bas android',
#  'aplikasi encoding protocol data unit pdu short message service sms kembang kendali pc guna mobile',
#  'aplikasi email untuk tuna netra',
#  'aplikasi email bas wap message service',
#  'aplikasi electronic government gc government to citizen layan kartu tanda duduk bas web',
#  'aplikasi elearning bas web untuk smk studi kasus smk muhammadiyah  moyudan',
#  'aplikasi edakwah bas ponsel guna wap',
#  'aplikasi ecomerce pasar buku online cv diandra primamitra media php mysql',
#  'aplikasi deteksi tepi untuk kenal bentuk daun guna operator prewitt',
#  'aplikasi tentu rusa jalan studi kasus bappeda kota yogyakarta',
#  'aplikasi cuti online pt gunung bayan pratama coal balikpapan',
#  'aplikasi customer relationship management untuk mesan tiket bus bas short message service studi kasus agen bus cepat budiman yogyakarta',
#  'aplikasi customer relationship management jenis customer support bas web studi kasus po sumber alam kutoarjo purworejo',
#  'aplikasi costumer relationship management jenis costumer self service bas short message services',
#  'aplikasi billing warnet bas client server guna microsoft winsock control  ',
#  'aplikasi bantu simpan data perangkat mobile untuk aplikasi kelola uang komputer',
#  'aplikasi bantu selesai akuntansi',
#  'aplikasi bantu ajar selesai sistem sama linier guna metode gauss gauss jordan atur cramer matakuliah aljabar linier matriks',
#  'aplikasi bantu ajar online perangkat mobile studi kasus prodi teknik informatika uad',
#  'aplikasi akses informasi lembaga bimbing ajar bas sms gateway over gprs general packet radio service',
#  'animasi simulasi tangan awal jadi bakar gedung rumah sakit tingkat',
#  'animasi suluh milu',
#  'animasi guna alat selamat bus akap untuk tingkat paham guna alat selamat pemumpang guna metode simulasi',
#  'animasi demonstrasi cara sikat gigi anak',
#  'animasi bahaya anemia ibu hamil guna metode frame by frame motion tween',
#  'animasi prosedur buat panjang surat izin kemudi',
#  'animasi d bas limited cut animation post planning animation untuk tingkat paham tokoh gatotkaca anak smp',
#  'analisis banding teknik segmentasi citra digital guna metode levelset chan vese lakton',
#  'analisis banding metode two dimensional median filte multi level median filter filtering citra digital',
#  'analisis banding metode high pass intensisty filtering metode median filtering untuk kurang derau citra digital',
# ...
#  'kembang multimedia ajar fisika articulate storyline pokok bahas gelombang kelas viii smp mts',
#  'kembang multimedia ajar bas moodle pokok bahas integral untuk serta didik sma kelas xii',
#  'kembang multimedia ajar bas komputer materi optik kelas viii guna adobe flash c',
#  'kembang multimedia pembelajaranmatematika guna macromediaflash  pokok bahas trigonometriuntuk smk kelas x jurus teknik audiovideo',
#  'kembang multimedia lectora integrasi stem untuk tingkat mandiri ajar subtema ciri makhluk hidup siswa kelas iii sd',
#  'kembang multimedia lectora inspire integrasi stem karakter peduli lingkung kelas v sd',
#  'kembang multimedia interaktif ajar matematika bas macromedia flash  materi garis sudut untuk siswa smp mts',
#  'kembang multimedia interaktif materi golong hewan mata ajar ipa guna adobe flash pro cs  untuk siswa kelas iii sd',
#  'kembang multimedia interaktif mata ajar bahasa indonesia ajar keterampilanmembaca siswa kelas x smk negeri  yogyakarta tahun ajar  ',
#  'kembang multimedia interaktif bas lectora inspire subtema sumber energi siswa kelas iv sekolah dasar',
#  'kembang multimedia interaktif adobe flash cs ajar teks cerpen siswa kelas vii smp n  yogyakarta tahun ajar  ',
#  'kembang multimedia elearning online bas moodle pokok bahas lingkar untuk siswa smp kelas viii',
#  'kembang multimedia bas animasi  dimensi ajar fisika guna adobe flash pokok bahas pesawat sederhana',
#  'kembang media ajar matematika bas multimedia siswa sekolah dasar',
#  'kembang media ajar matematika bas multimedia interaktif guna macromedia flash professional  siswa smp mts kelas viii pokok bahas sama garis lurus',
#  'kembang media ajar matematika bas multimedia interaktif guna macromedia flash  pokok bahas sistem sama linear dua variabel untuk smp kelas viii',
#  'kembang media ajar matematika bas multimedia interaktif guna macromedia flash  pokok bahas bangun datar segi empat untuk smp kelas vii',
#  'kembang media ajar matematika bas multimedia interaktif guna adobe flash cs  materi operasi bentuk aljabar untuk siswa smp kelas viii',
#  'kembang media ajar matematika bas multimedia interaktif guna adobe flash cs  pokok bahas atur cacah sma kelas xi jurus ipa',
#  'kembang media ajar matematika bas multimedia interaktif guna adobe flash cs  materiprogram linear dekat scientific sma smk kelas xi',
#  'kembang media ajar matematika bas multimedia interaktif adobe flash cs pokok bahas operasi aljabar untuk smp mts',
#  'kembang media ajar interaktif bas multimedia guna macromedia flash  materi sama linier satu variabel untuk smp kelas vii',
#  'kembang media ajar interaktif bas multimedia guna articulate storyline  untuk siswa sma kelas xi materi suhu kalor',
#  'kembang media ajar interaktif bas multimedia komputer materi struktur fungsi jaring tumbuh untuk siswa sma kelas xi',
#  'kembang media ajar',
#  'emang multimedia interaktif ajar fisika bas lectora inspire materi suhu untuk smp kelas vii',
#  'pengaruh media ajar multimedia interaktif minat ajar pai siswa kelas x smk negeri  won',
#  'pengaruh implementasi multimedia interaktif danmotivasi ajar prestasi ajar padapembelajaran materi impuls momentum kelas xisma',
#  'terap multimedia interaktif macromedia flash mata ajar didik agama islam tingkat motivasi ajar siswa kelas x smkn  depok sleman yogyakarta tahun ajar  ',
#  'tentu karakteristik alat musik saron selendro sistem multimedia based laboratory',
#  'ajar studi matematika luas volume bangun ruang alas lingkar bas multimedia untuk siswa kelas ix studi kasus smp negeri  mojoagung',
#  'ajar bahasa jepang dasar bas multimedia',
#  'multimedia ajar bidang studi biologi virus sebar untuk sma kelas x',
#  'multimedia sarana informasi seni budaya pariwisata kabupaten karawang',
#  'multimedia ajar cermin lensa bas web',
#  'multimedia interaktif media informasi pasar seni gabus bantul yogyakarta',
#  'multimedia filterkloraktif kelola air gambut sungai kabupaten kapuas kalimantan tengah',
#  'memmbangun aplikasi ajar teknik bekam bentuk tutorial bas multimedia',
#  'bangun aplikasi ajar teknik bekam bentuk tutorial bas multimedia',
#  'bangun sistem ajar kenal bentuk anak multimedia game',
#  'bangun perangkat lunak hitung sempoa bas multimedia',
#  'bangun pandu kuliah grafika multimedia dinamis bas multimedia interaktif',
#  'bangun distro linux forti   untuk butuh multimedia',
#  'bangun computer assisted instruction cai bas multimedia untuk mata ajar ilmu tahu alam materi pokok sistem gerak manusia studi pustaka smpn  manisrenggo klaten',
#  'bangun aplikasi multimedia program ajar sains sistem cerna manusia kelas viii studi kasus smp  wates asih kulonprogo',
#  'media promosi ambarukmo plaza bas multimedia interaktif',
#  'media informasi wisata kuliner rawa jombor klaten bas multimedia',
#  'media bantu ajar bahasa jawa sinonim dasanama bahasa jawa bas multimedia untuk siswa sekolah dasar kelas v studi kasus sdn  glagah',
#  'media simulasi gamelan untuk sd islamiyah warungboto bas multimedia',
#  'media pembelajran bahasa inggris animals untuk taman kanakkanak bas multimedia',
#  'media ajar tafsir hadits bas multimedia',
#  'media ajar service handphone bas multimedia',
#  'media ajar renang bas multimedia interaktif untuk tingkat paham siswa mata ajar penjaskes',
#  'media ajar materi kenal open gl mata kuliah gafika komputer',
#  'media ajar mata ajar fisika materi pokok elastisitas fluida kelas xi bas multimedia studi kasus sma  kota bima ntb',
#  'media ajar mata ajar fisikamateri pokok elastisitas fluida kelas xiberbasis multimedia studi kasus sma  kota bima ntb',
#  'media ajar learning vector quantization bas multimedia untuk mudah paham mahasiswa matakuliah jaring saraf tiru',
#  'media ajar knapsack problem mata kuliah algoritma genetika bas multimedia',
#  'media ajar cerdas buat pokok bahas metode lacak guna multimedia elearning',
#  'media ajar job safety induction untuk siswa baru smk negeri  tasikmalaya program ahli mesin bas multimedia interaktif',
#  'media ajar interaktif pramuka latih tangkas barisberbaris guna tongkat bas multimedia sma negeri  mataram',
#  'media ajar interaktif pokok bahas ipa kelas vi tata surya bas multimedia sd insan kreatif kembar yogyakarta',
#  'media ajar interaktif materi kenampakan alam dan ada sosial indonesia negara tetangga mata ajar ips kelas vi sd',
#  'media ajar interaktif matematika kelas v kubus balok sekolah dasar negeri warungboto',
#  'media ajar interaktif mata ajar kimia materi hidrokarbon bas multimedia',
#  'media ajar interaktif rajin bahan lunak wirausaha bas multimedia mata ajar prakarya kewirausahaan untuk kelas xi semester  smk negeri  asih',
#  'media ajar interaktif ipa kelas vi materi energi listrik bas multimedia guna macromedia flash sd muhammadiyah ambarketawang  yogyakarta',
#  'media ajar interaktif dinamis mata ajar fisika materi hukum newton bas multimedia untuk siswa kelas x studi kasus sma muhammadiyah ',
#  'media ajar interakif mata ajar fisika materi listrik statis bas multimedia studi kasus muhammadiyah sukoharjo',
#  'media ajar fisika materi energi usaha untuk siswa smp kelas viii bas multimedia',
#  'media ajar bidirectional associative memory bam matakuliah jaring saraf tiru bas multimedia',
#  'media ajar bahasa inggris alphabet untuk taman kanakkanak bas multimedia',
#  'media ajar bahasa inggris parts of body untuk taman kanakkanak bas multimedia',
#  'media ajar bahasa inggris numbering untuk taman kanak kanak bas multimedia studi kasus tk it salman alfarisi yogyakarta',
#  'media ajar bahasa inggris colors untuk taman kanakkanak bas multimedia',
#  'media ajar bahasa inggris clother untuk taman kanak bas multimedia studi kasus tk salman al farisi',
#  'media ajar aksara sumbawa bas multimedia ajar muat lokal',
#  'media intruksional geografi smp kelas vii bas multimedia sub pokok bahas bentuk muka bumi',
#  'media informasi pariwisata kabupaten bengkal propinsi riau bas multimedia',
#  'media informasi rajin perak salim silver bas multimedia film dokumenter',
#  'media informasi rajin gerabah insan keramik kasongan yogyakarta bas multimedia',
#  'media hewan bantu ajar struktur fungsi sel tumbuh bas multimedia',
#  'media bantu ajar struktur fungsi sel tumbuh hewan bas multimedia',
#  'multimedia ajar topologi jaring bas mobile studi kasus smk nasional bah yogyakarta',
#  'media ajar shalat jamaah bas multimedia',
#  'media ajar kenal jenis  jenis tumbuh bas multimedia studi kasus tk tunas melati yogyakarta',
#  'media ajar bahasa inggris bas multimedia client server untuk kelas viii smpn  piyungan bantul yogyakarta',
#  'media bantu ajar fisika sub pokok bahas usaha energi untuk sma kelas xi bas multimedia',
#  'media bantu ajar bahasa inggris untuk taman kanakkanak bas multimedia',
#  'mediapembelajaranmenyambunghurufhijaiyahberbasismultimedia',
#  'komputerisasi english for kindergarten tata surya bas multimedia',
#  'informasi fiqih wanita tata cara mandi wajib bas multimedia turut hadis rasulullah',
#  'implementasi profil wisata museum gula jawa tengah gondang baru klaten bas multimedia',
#  'implementasi profil wisata dieng jawa tengah bas multimedia',
#  'implementasi multimedia alat bantu ajar materi geometri citra mata kuliah computer vision',
#  'implementasi multimedia alat bantu ajar mata kuliah statistik informatika untuk materi uji hipotesis',
#  'implementasi metode motion graphic video animation daftar offline mahasiswa baru universitas ahmad dahlan',
#  'implementasi media ajar macromedia flash mata ajar matematika',
#  'implementasi ajar iqro untuk anankanak serta ucap bas multimedia studi kasus madrasah tarbiyatul athfal',
#  'iformasi hotel tanjung beach resort lamongan bas multimedia interaktif',
#  'ibm aplikasi ajar multimedia untuk guru bk smkn  smkn  yogyakarta',
#  'integrasi tpack kembang multimedia bas powtoon ajar pokok bahas gelombang jalan gelombang stasioner sma muhamamdiyah  yogyakarta',
#  'implementasi profil pariwisata budaya kab bengkulu selatan  bahasa bas multimedia',
#  'hubung prestasi ajar mata ajar program juru minat studi lanjut siswa kelas xi multimedia smk negeri  won tahun ajar  ',
#  'game interaktif tebak kata bahasa indonesia untuk anak sd guna makromedia flash bas multimedia',
#  'film dokumenter desa wisata daerah istimewa yogyakarta bas multimedia',
#  'edukasi sehat reproduksi remaja guna aplikasi multimedia',
#  'eguide letak ruang pasien rsu pku muhammadiyah yogyakarta bas multimedia',
#  'developing the interactive english learning multimedia for the second grade students of sma n  pundong',
#  'developing english imteractive multimedia for nursing students at nursing academy akper serulingmas cilacap',
#  'developing an interactive multimedia program for reading comprehension learning for the eleventh grade students of ma muallimin muhammadiyah yogyakarta',
#  'desain implementasi media sosialisasi bahaya rokok tanggulang bas multimedia',
#  'desain implementasi aplikasi multimedia budidaya anggrek',
#  'developing writing tasks based on interactivemultimedia for the tenth grade students ofsma tamanmadya ibu pawiyatan yogyakarta',
#  'developing the interactive english learning multimedia for the first grade of smk n  yogyakarta',
#  'developing the interactive english learning multimedia for grade viii students of smp muhammadiyah  yogyakarta',
#  'developing macromedia flash for learning writing skill of the fifth grade in sd n lempuyangan  academic year  ',
#  'developing interactive multimedia for teaching reading to the eighth grade students of mts muhammadiyah merden banjarnegara',
#  'developing interactive multimedia for learning reading and writing learning materials for grade vii students of smp n  yogyakarta',
#  'designing english multimedia material for speaking ability for elementary school students',
#  'designing an english textbook for multimedia class of smk muhammadiyah  yogyakarta by using contextual teaching and learning approach',
#  'computer assisted intruction aksara jawa bas multimedia studi kasus smp negeri  paliyan gunungkidul',
#  'cd interaktif pariwisata kabupaten padeglang bas multimedia',
#  'cd interaktif alat bantu ajar microsoft office power point ',
#  'biografi kyai haji ahmad dahlan bas multimedia',
#  'appraisal on the effectiveness of multimedia technology in english enrichment classes',
#  'aplikasi pembeljaran iqra bas multimedia',
#  'aplikasi ajar cinta alam bas multimedia',
#  'aplikasi multimedia jendela informasi badan rumah sakit daerah wonosobo',
#  'aplikasi profil wisata taman kyai langgeng magelang cara online bas multimedia',
#  'aplikasi kenal huruf hiragana jepang bas multimedia interaktif',
#  'aplikasi ajar wudhu tayammum shalat wajib bentuk animasi  dimensi bas multimedia untuk umum guna ds max ',
#  'aplikasi ajar fisika sub pokok bahas alat optik bas multimedia',
#  'aplikasi pandu ajar sistem edar darah manusia bas multimedia studi kasus pandu ajar mata kuliah anatomi fisiologi stikes aisyiyah yogyakarta',
#  'aplikasi multimedia narkoba proses rusa organ tubuh manusia',
#  'aplikasi multimedia alternatif media promosi pariwisata candi borobudur',
#  'aplikasi multimedia proses salin normal untuk dukung ajar program studi bidan stikes aisyiyah yogyakarta',
#  'aplikasi multimedia objek wisata kota bukittinggi guna animasi peta lokasi',
#  'aplikasi multimedia interaktif untuk pariwisata kabupaten semarang guna macromedia flash',
#  'aplikasi multimedia interaktif model addie mata ajar pancasila',
#  'aplikasi multimedia interaktif sarana informasi museum sangir sragen',
#  'aplikasi multimedia interaktif mata ajar teknologi informasi komunikasi untuk kelas xi sekolah tengah atas studi kasus man i yogyakarta',
#  'aplikasi media ajar interaktif ipa untuk siswa kelas v sd materi ekosistem bas multimedia',
#  'aplikasi computerassisted learning ajar sistem tata surya gerhana bas multimedia',
#  'aplikasi computer assisted learning cal kenal huruf angka untuk siswa kelas  sd negeri golo yogyakarta',
#  'aplikasi alat transportasi bahasa inggrisuntuk taman kanakkanak bas multimedia studi kasus tk dharma bakti yogyakarta',
#  'alat bantu ajar dinamika partikel bas multimedia',
#  'aplikasi ajar bahasa arab anak prasekolah bas multimedia studi kasus tk uswatun hasanah yogyakarta',
#  'aplikasi media ajar matematika sekolah tengah atas kelas xii materi vektor bas multimedia studi kasus sma ma arif wates kulon progo',
#  'animasi dongeng kancil buaya pesan moral untuk anak bas multimedia',
#  'aplikasi kenal pakai rumah adat indonesia bas multimedia studi kasus sd muhammadiyah sukonandi ii yogyakarta',
#  'sistem informasi bas web untuk usaha retail',
#  'wireless application protocol wap untuk sistem informasi jadwal kuliah',
#  'teknologi web serviceuntuk integrasi aplikasi studi kasus sipenta simak tanakung priyanta',
#  'studi sistem informasi akuntansi piutang pasien rsu pku muhammadiyah bantul',
#  'ssitem informasi aji pt tunas agung lestari guna php mysql',
#  'sistem reservasi tiket wisata online bas mobile web',
#  'sistem hitung layana informasi naik jabat dosen bas sms studi kasus fmipa prodi sistem informasi uad',
#  'sistem bayar sekolah bas web studi kasus sma muh  yogyakarta',
#  'sistem pakar untuk mendiagnosa hama sakit tanam padi guna cetainty factor cf',
#  'sistem informasi rekam medis rumah sakit sus ibu anak ummi khasanah bas web',
#  'sistem informasi pustaka bas web php mysql',
#  'sistem informasi awat kendara universitas ahmad dahlan guna aplikasi visual basic  ',
#  'sistem informasi jual padu swalayan betta guna hardware pos point of sales',
#  'sistem informasi gaji karyawan cv cipto moro abadi sawn timber wood',
#  'sistem informasi terima calon mahasiswa baru bas web guna php mysql',
#  'sistem informasi daftar pasien layan sehat bas sms',
#  'sistem informasi mesan tiket wisata online',
#  'sistem informasi mesan tari cara online media promosi bas web studi kasus sanggar seni sinten remen batumarta oku induk',
#  'sistem informasi pariwisata kabupaten tuban tehnologi sistem informasi geografis sig',
#  'sistem informasi manajemen pegawai bas jaring kantor wilayah departemen agama propinsi diy',
#  'sistem informasi manajemen apotik studi kasus apotek dantisa',
#  ...]

# %%
dataset['preprocessed_title'] = pre

# %%
dataset
# Out:
#                     author                                              title  \
# 0       Sari Ismu Banjaran  Perancangan Model Supply Chain Management (Scm...
# 1               Edi Irawan  Website Update Skor Pertandingan Sepak Bola Li...
# 2                 Nurwahid  Web Service Backend Manajemen Perpustakaan Des...
# 3                   Marwan  Visualisasi Teknik Pengobatan Akupuntur Dengan...
# 4           Heru Kurniawan  Visualisasi Proses Enkripsi Dan Deskripsi Meto...
# ...                    ...                                                ...
# 1706      Sovian Rizqiawan  Aplikasi Pengolahan Citra Untuk Identifikasi K...
# 1707   Ervita Kusuma Putri  Penerapan Text Mining Pada Sistem Klasifikasi ...
# 1708     Nila Hutami Putri  Penerapan Text Mining Untuk Pengelompokan Tren...
# 1709    Ika Kurnia Saputri  Penerapan Text Mining Pengelompokkan Judul Ker...
# 1710          Rika Nursita  Penerapan Text Mining Pengelompokan Judul Mana...
#
#                                                     url  year  \
# 0     http://digilib.uad.ac.id/penelitian/Penelitian...  2014
# 1     http://digilib.uad.ac.id/penelitian/Penelitian...  2012
# 2     http://digilib.uad.ac.id/penelitian/Penelitian...  2015
# 3     http://digilib.uad.ac.id/penelitian/Penelitian...  2014
# 4     http://digilib.uad.ac.id/penelitian/Penelitian...  2013
# ...                                                 ...   ...
# 1706  http://digilib.uad.ac.id/penelitian/Penelitian...  2016
# 1707  http://digilib.uad.ac.id/penelitian/Penelitian...  2014
# 1708  http://digilib.uad.ac.id/penelitian/Penelitian...  2018
# 1709  http://digilib.uad.ac.id/penelitian/Penelitian...  2017
# 1710  http://digilib.uad.ac.id/penelitian/Penelitian...  2019
#
#                                      preprocessed_title
# 0     ancang model supply chain management scm anali...
# 1     website update skor tanding sepak bola liga in...
# 2     web service backend manajemen pustaka desa bas...
# 3           visualisasi teknik obat akupuntur animasi d
# 4     visualisasi proses enkripsi deskripsi metode a...
# ...                                                 ...
# 1706  aplikasi olah citra untuk identifikasi matang ...
# 1707  terap text mining sistem klasifikasi email spa...
# 1708  terap text mining untuk kelompok trend judul s...
# 1709  terap text mining kelompok judul kerja praktek...
# 1710  terap text mining kelompok judul manajemen tug...
#
# [1711 rows x 5 columns]

# %%
dataset.to_excel("dataset_preprocessing.xlsx", index=False)
