# %%
import pandas as pd

# %%
old = pd.read_excel("dataset_raw.xlsx")
old
# Out:
#                         author  \
# 0           Sari Ismu Banjaran
# 1                   Edi Irawan
# 2                     Nurwahid
# 3                       Marwan
# 4               Heru Kurniawan
# ...                        ...
# 1702             Ummi Syafiqoh
# 1703            Adhi Saifuddin
# 1704           Mukhlis Mukhtar
# 1705   Budi Handarbeni S. Atma
# 1706          Sovian Rizqiawan
#
#                                                   title  \
# 0     Perancangan Model Supply Chain Management (Scm...
# 1     Website Update Skor Pertandingan Sepak Bola Li...
# 2     Web Service Backend Manajemen Perpustakaan Des...
# 3     Visualisasi Teknik Pengobatan Akupuntur Dengan...
# 4     Visualisasi Proses Enkripsi Dan Deskripsi Meto...
# ...                                                 ...
# 1702  Analisis Fungsi Keanggotaan Metode Fuzzy Tsuka...
# 1703  Alat Pendeteksi Kualitas Daging Sapi Berdasark...
# 1704  Alat Bantu Ajar Mata Kuliah Fuzzy Logic Pada P...
# ...

# %%
scrapper = pd.read_excel("dataset_scrapper.xlsx")
newdata = old.append(scrapper, ignore_index=True)

# %%
newdata.to_excel("dataset_raw.xlsx", index=False)

# %%
new = pd.read_excel("dataset_raw.xlsx")
new.drop_duplicates(keep=False,inplace=True)
new.dropna()
new.to_excel("dataset_raw.xlsx", index=False)

# %%
nn = pd.read_excel("dataset_raw.xlsx")
nn.dropna()
nn.to_excel("dataset_raw.xlsx", index=False)
nn
# Out:
#                     author                                              title  \
# 0       Sari Ismu Banjaran  Perancangan Model Supply Chain Management (Scm...
# 1               Edi Irawan  Website Update Skor Pertandingan Sepak Bola Li...
# 2                 Nurwahid  Web Service Backend Manajemen Perpustakaan Des...
# 3                   Marwan  Visualisasi Teknik Pengobatan Akupuntur Dengan...
# 4           Heru Kurniawan  Visualisasi Proses Enkripsi Dan Deskripsi Meto...
# ...                    ...                                                ...
# 1706      Sovian Rizqiawan  Aplikasi Pengolahan Citra Untuk Identifikasi K...
# 1707   Ervita Kusuma Putri  Penerapan Text Mining Pada Sistem Klasifikasi ...
# 1708     Nila Hutami Putri  Penerapan Text Mining Untuk Pengelompokan Tren...
# 1709    Ika Kurnia Saputri  Penerapan Text Mining Pengelompokkan Judul Ker...
# 1710          Rika Nursita  Penerapan Text Mining Pengelompokan Judul Mana...
#
# ...
